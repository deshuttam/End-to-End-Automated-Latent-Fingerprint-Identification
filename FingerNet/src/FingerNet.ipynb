# %%
import os

# %%
os.getcwd()
# Out:
# '/content'

# %%
# !pip install pydrive                             # Package to use Google Drive API - not installed in Colab VM by default
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
# Out:
# Collecting pydrive
#   Downloading https://files.pythonhosted.org/packages/6b/2d/c8e052ba51099faee0bfe71d84f35bb1576e6910483cad46b840a122ca6c/PyDrive-1.3.1-py2-none-any.whl
# Requirement already satisfied: PyYAML>=3.0 in /usr/local/lib/python2.7/dist-packages (from pydrive) (3.13)
# Requirement already satisfied: oauth2client>=4.0.0 in /usr/local/lib/python2.7/dist-packages (from pydrive) (4.1.3)
# Requirement already satisfied: google-api-python-client>=1.2 in /usr/local/lib/python2.7/dist-packages (from pydrive) (1.7.9)
# Requirement already satisfied: httplib2>=0.9.1 in /usr/local/lib/python2.7/dist-packages (from oauth2client>=4.0.0->pydrive) (0.11.3)
# Requirement already satisfied: rsa>=3.1.4 in /usr/local/lib/python2.7/dist-packages (from oauth2client>=4.0.0->pydrive) (4.0)
# Requirement already satisfied: pyasn1>=0.1.7 in /usr/local/lib/python2.7/dist-packages (from oauth2client>=4.0.0->pydrive) (0.4.5)
# Requirement already satisfied: pyasn1-modules>=0.0.5 in /usr/local/lib/python2.7/dist-packages (from oauth2client>=4.0.0->pydrive) (0.2.5)
# Requirement already satisfied: six>=1.6.1 in /usr/local/lib/python2.7/dist-packages (from oauth2client>=4.0.0->pydrive) (1.15.0)
# Requirement already satisfied: google-auth-httplib2>=0.0.3 in /usr/local/lib/python2.7/dist-packages (from google-api-python-client>=1.2->pydrive) (0.0.3)
# Requirement already satisfied: google-auth>=1.4.1 in /usr/local/lib/python2.7/dist-packages (from google-api-python-client>=1.2->pydrive) (1.17.2)
# Requirement already satisfied: uritemplate<4dev,>=3.0.0 in /usr/local/lib/python2.7/dist-packages (from google-api-python-client>=1.2->pydrive) (3.0.0)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python2.7/dist-packages (from google-auth>=1.4.1->google-api-python-client>=1.2->pydrive) (3.1.1)
# Requirement already satisfied: setuptools>=40.3.0 in /usr/local/lib/python2.7/dist-packages (from google-auth>=1.4.1->google-api-python-client>=1.2->pydrive) (44.1.1)
# Installing collected packages: pydrive
# Successfully installed pydrive-1.3.1

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
os.chdir('drive/My Drive/FingerNet/FingerNet/src/')

# %%
#
#os.chdir('drive/My Drive/Colab Notebooks/LearnNet/CoarseNet')
os.getcwd()
# Out:
# '/content/drive/My Drive/FingerNet/FingerNet/src'

# %%
# !pip install keras==2.0.2
# Out:
# Collecting keras==2.0.2
#   Downloading https://files.pythonhosted.org/packages/0f/00/ffbeaa7185c5e6ea49e982d804f7e388908916eceb2a8c8a9ed0bd5cf045/Keras-2.0.2.tar.gz (192kB)
#      |████████████████████████████████| 194kB 6.8MB/s
# Requirement already satisfied: theano in /usr/local/lib/python2.7/dist-packages (from keras==2.0.2) (1.0.4)
# Requirement already satisfied: pyyaml in /usr/local/lib/python2.7/dist-packages (from keras==2.0.2) (3.13)
# Requirement already satisfied: six in /usr/local/lib/python2.7/dist-packages (from keras==2.0.2) (1.15.0)
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python2.7/dist-packages (from theano->keras==2.0.2) (1.16.4)
# Requirement already satisfied: scipy>=0.14 in /usr/local/lib/python2.7/dist-packages (from theano->keras==2.0.2) (1.2.2)
# Building wheels for collected packages: keras
#   Building wheel for keras (setup.py) ... done
#   Created wheel for keras: filename=Keras-2.0.2-cp27-none-any.whl size=228897 sha256=0c6ad5619df33ecf87d43d820a43ce9bc1a944e50dadd798c6951e87cce530e9
#   Stored in directory: /root/.cache/pip/wheels/78/38/73/74028957a9c42049a56878c4bb8a2c732c3e205f599fb9b384
# Successfully built keras
# Installing collected packages: keras
#   Found existing installation: Keras 2.3.1
#     Uninstalling Keras-2.3.1:
#       Successfully uninstalled Keras-2.3.1
# Successfully installed keras-2.0.2

# %%
# !pip install tensorflow==1.0.1
# Out:
# Collecting tensorflow==1.0.1
#   Downloading https://files.pythonhosted.org/packages/7e/7c/f398393beab1647be0a5e6974b8a34e4ea2d3cb7bd9e38bd43a657ed27d1/tensorflow-1.0.1-cp27-cp27mu-manylinux1_x86_64.whl (44.1MB)
#      |████████████████████████████████| 44.1MB 96kB/s
# Requirement already satisfied: numpy>=1.11.0 in /usr/local/lib/python2.7/dist-packages (from tensorflow==1.0.1) (1.16.4)
# Requirement already satisfied: mock>=2.0.0 in /usr/local/lib/python2.7/dist-packages (from tensorflow==1.0.1) (2.0.0)
# Requirement already satisfied: wheel in /usr/local/lib/python2.7/dist-packages (from tensorflow==1.0.1) (0.36.0)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python2.7/dist-packages (from tensorflow==1.0.1) (1.15.0)
# Requirement already satisfied: protobuf>=3.1.0 in /usr/local/lib/python2.7/dist-packages (from tensorflow==1.0.1) (3.8.0)
# Requirement already satisfied: funcsigs>=1; python_version < "3.3" in /usr/local/lib/python2.7/dist-packages (from mock>=2.0.0->tensorflow==1.0.1) (1.0.2)
# Requirement already satisfied: pbr>=0.11 in /usr/local/lib/python2.7/dist-packages (from mock>=2.0.0->tensorflow==1.0.1) (5.4.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python2.7/dist-packages (from protobuf>=3.1.0->tensorflow==1.0.1) (44.1.1)
# Installing collected packages: tensorflow
#   Found existing installation: tensorflow 2.1.0
#     Uninstalling tensorflow-2.1.0:
#       Successfully uninstalled tensorflow-2.1.0
# Successfully installed tensorflow-1.0.1

# %%
from google.colab import auth                    # Other necessary packages
from oauth2client.client import GoogleCredentials

# %%
auth.authenticate_user()                         # Follow prompt in the authorization process
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()

# %%
drive = GoogleDrive(gauth)
your_module = drive.CreateFile({"id": "1OiYok7xTOEPEHXzF2FCUM-Q1kCZCPbtZ"})   # "your_module_file_id" is the part after "id=" in the shareable link
your_module.GetContentFile("utils.py")          # Save the .py module file to Colab VM
import utils
# Out:
# utils.py:9: UserWarning:
# This call to matplotlib.use() has no effect because the backend has already
# been chosen; matplotlib.use() must be called *before* pylab, matplotlib.pyplot,
# or matplotlib.backends is imported for the first time.
#
# The backend was *originally* set to 'module://ipykernel.pylab.backend_inline' by the following code:
#   File "/usr/lib/python2.7/runpy.py", line 174, in _run_module_as_main
#     "__main__", fname, loader, pkg_name)
#   File "/usr/lib/python2.7/runpy.py", line 72, in _run_code
#     exec code in run_globals
#   File "/usr/local/lib/python2.7/dist-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/usr/local/lib/python2.7/dist-packages/traitlets/config/application.py", line 658, in launch_instance
#     app.start()
#   File "/usr/local/lib/python2.7/dist-packages/ipykernel/kernelapp.py", line 499, in start
#     self.io_loop.start()
#   File "/usr/local/lib/python2.7/dist-packages/tornado/ioloop.py", line 888, in start
#     handler_func(fd_obj, events)
#   File "/usr/local/lib/python2.7/dist-packages/tornado/stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/usr/local/lib/python2.7/dist-packages/zmq/eventloop/zmqstream.py", line 456, in _handle_events
#     self._handle_recv()
#   File "/usr/local/lib/python2.7/dist-packages/zmq/eventloop/zmqstream.py", line 486, in _handle_recv
#     self._run_callback(callback, msg)
#   File "/usr/local/lib/python2.7/dist-packages/zmq/eventloop/zmqstream.py", line 438, in _run_callback
#     callback(*args, **kwargs)
#   File "/usr/local/lib/python2.7/dist-packages/tornado/stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/usr/local/lib/python2.7/dist-packages/ipykernel/kernelbase.py", line 283, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "/usr/local/lib/python2.7/dist-packages/ipykernel/kernelbase.py", line 233, in dispatch_shell
#     handler(stream, idents, msg)
#   File "/usr/local/lib/python2.7/dist-packages/ipykernel/kernelbase.py", line 399, in execute_request
#     user_expressions, allow_stdin)
#   File "/usr/local/lib/python2.7/dist-packages/ipykernel/ipkernel.py", line 208, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/usr/local/lib/python2.7/dist-packages/ipykernel/zmqshell.py", line 537, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/usr/local/lib/python2.7/dist-packages/IPython/core/interactiveshell.py", line 2728, in run_cell
#     self.events.trigger('post_run_cell')
#   File "/usr/local/lib/python2.7/dist-packages/google/colab/_event_manager.py", line 28, in trigger
#     func(*args, **kwargs)
#   File "/usr/local/lib/python2.7/dist-packages/ipykernel/pylab/backend_inline.py", line 164, in configure_once
#     activate_matplotlib(backend)
#   File "/usr/local/lib/python2.7/dist-packages/IPython/core/pylabtools.py", line 309, in activate_matplotlib
#     matplotlib.pyplot.switch_backend(backend)
#   File "/usr/local/lib/python2.7/dist-packages/matplotlib/pyplot.py", line 231, in switch_backend
#     matplotlib.use(newbackend, warn=False, force=True)
#   File "/usr/local/lib/python2.7/dist-packages/matplotlib/__init__.py", line 1422, in use
#     reload(sys.modules['matplotlib.backends'])
#   File "/usr/local/lib/python2.7/dist-packages/matplotlib/backends/__init__.py", line 17, in <module>
#     line for line in traceback.format_stack()
#
#
#   matplotlib.use('Agg')

# %%
#
#os.chdir('drive/My Drive/Colab Notebooks/LearnNet/CoarseNet')
os.getcwd()
# Out:
# '/content/drive/My Drive/FingerNet/FingerNet/src'

# %%
#coding=utf-8
import os, sys, cv2, pickle
from multiprocessing import Pool
from functools import partial
from time import time
import matplotlib
# Force matplotlib to not use any Xwindows backend.
#matplotlib.use('Agg')
import matplotlib.pyplot as plt
from datetime import datetime
from utils import *
from scipy import misc, ndimage, signal, sparse, io

from keras import backend as K
from keras.models import Model
from keras.layers import Input
from keras.layers.core import Flatten,Activation,Lambda
from keras.layers.convolutional import Conv2D,MaxPooling2D,UpSampling2D
from keras.layers.normalization import BatchNormalization
from keras.layers.advanced_activations import PReLU
from keras.regularizers import l2
from keras.optimizers import SGD, Adam
from keras.utils import plot_model
from keras.callbacks import ModelCheckpoint  
import tensorflow as tf

#import argparse
#parser = argparse.ArgumentParser(description='Train-Test-Deploy')
#parser.add_argument('GPU', type=str, default="4", help='Your GPU ID')
#parser.add_argument('mode', type=str, default="train", help='train-test, test or deploy')
#args = parser.parse_args()

#os.environ["CUDA_VISIBLE_DEVICES"]=args.GPU
#config = K.tf.ConfigProto(gpu_options=K.tf.GPUOptions(allow_growth=True))
#sess = K.tf.Session(config=config)
#K.set_session(sess)

mode = 'deploy'
#mode = 'test'
#mode = 'train'
#os.environ["CUDA_VISIBLE_DEVICES"] = '1'
os.environ["CUDA_VISIBLE_DEVICES"] = '0'
config = K.tf.ConfigProto(gpu_options=K.tf.GPUOptions(allow_growth=True))
sess = K.tf.Session(config=config)
K.set_session(sess)
root=os.getcwd()




batch_size = 2
use_multiprocessing = False
#train_set = ['../datasets/CISL24218/',]
#train_set = ['../datasets/NISTSD27/images/']
train_set = ['../datasets/NISTSD27/',]
train_sample_rate = None
test_set = ['../datasets/NISTSD27/',]
#deploy_set = ['../datasets/NISTSD27/images/','../datasets/CISL24218/', \
#           '../datasets/FVC2002DB2A/','../datasets/NIST4/','../datasets/NIST14/']
deploy_set = ['../datasets/NISTSD27/images/']
pretrain = '../models/released_version/Model.model'
output_dir = '../output/'+datetime.now().strftime('%Y%m%d-%H%M%S')
logging = init_log(output_dir)
copy_file(sys.path[0]+'/'+sys.argv[0], output_dir+'/')

# image normalization
def img_normalization(img_input, m0=0.0, var0=1.0):
    m = K.mean(img_input, axis=[1,2,3], keepdims=True)
    var = K.var(img_input, axis=[1,2,3], keepdims=True)
    after = K.sqrt(var0*K.tf.square(img_input-m)/var)
    image_n = K.tf.where(K.tf.greater(img_input, m), m0+after, m0-after)
    return image_n

# atan2 function
def atan2(y_x):
    y, x = y_x[0], y_x[1]+K.epsilon()
    atan = K.tf.atan(y/x)
    angle = K.tf.where(K.tf.greater(x,0.0), atan, K.tf.zeros_like(x))
    angle = K.tf.where(K.tf.logical_and(K.tf.less(x,0.0),  K.tf.greater_equal(y,0.0)), atan+np.pi, angle)
    angle = K.tf.where(K.tf.logical_and(K.tf.less(x,0.0),  K.tf.less(y,0.0)), atan-np.pi, angle)
    return angle

# traditional orientation estimation
def orientation(image, stride=8, window=17):
    with K.tf.name_scope('orientation'):
        assert image.get_shape().as_list()[3] == 1, 'Images must be grayscale'
        strides = [1, stride, stride, 1]
        E = np.ones([window, window, 1, 1])
        sobelx = np.reshape(np.array([[-1, 0, 1], [-2, 0, 2], [-1, 0, 1]], dtype=float), [3, 3, 1, 1])
        sobely = np.reshape(np.array([[-1, -2, -1], [0, 0, 0], [1, 2, 1]], dtype=float), [3, 3, 1, 1])
        gaussian = np.reshape(gaussian2d((5, 5), 1), [5, 5, 1, 1])
        with K.tf.name_scope('sobel_gradient'):
            Ix = K.tf.nn.conv2d(image, sobelx, strides=[1,1,1,1], padding='SAME', name='sobel_x')
            Iy = K.tf.nn.conv2d(image, sobely, strides=[1,1,1,1], padding='SAME', name='sobel_y')
        with K.tf.name_scope('eltwise_1'):
            Ix2 = K.tf.multiply(Ix, Ix, name='IxIx')
            Iy2 = K.tf.multiply(Iy, Iy, name='IyIy')
            Ixy = K.tf.multiply(Ix, Iy, name='IxIy')
        with K.tf.name_scope('range_sum'):
            Gxx = K.tf.nn.conv2d(Ix2, E, strides=strides, padding='SAME', name='Gxx_sum')
            Gyy = K.tf.nn.conv2d(Iy2, E, strides=strides, padding='SAME', name='Gyy_sum')
            Gxy = K.tf.nn.conv2d(Ixy, E, strides=strides, padding='SAME', name='Gxy_sum')
        with K.tf.name_scope('eltwise_2'):
            Gxx_Gyy = K.tf.subtract(Gxx, Gyy, name='Gxx_Gyy')
            theta = atan2([2*Gxy, Gxx_Gyy]) + np.pi
        # two-dimensional low-pass filter: Gaussian filter here
        with K.tf.name_scope('gaussian_filter'):
            phi_x = K.tf.nn.conv2d(K.tf.cos(theta), gaussian, strides=[1,1,1,1], padding='SAME', name='gaussian_x')
            phi_y = K.tf.nn.conv2d(K.tf.sin(theta), gaussian, strides=[1,1,1,1], padding='SAME', name='gaussian_y')
            theta = atan2([phi_y, phi_x])/2
    return theta

def get_tra_ori():
    img_input=Input(shape=(None, None, 1))
    theta = Lambda(orientation)(img_input)
    model = Model(inputs=[img_input,], outputs=[theta,])
    return model
tra_ori_model = get_tra_ori()

def get_maximum_img_size_and_names(dataset, sample_rate=None):
    if sample_rate is None:
        sample_rate = [1]*len(dataset)
    img_name, folder_name, img_size = [], [], []
    for folder, rate in zip(dataset, sample_rate):
        _, img_name_t = get_files_in_folder(folder+'images/', '.bmp')
        img_name.extend(img_name_t.tolist()*rate)
        folder_name.extend([folder]*img_name_t.shape[0]*rate)
        img_size.append(np.array(misc.imread(folder+'images/'+img_name_t[0]+'.bmp', mode='L').shape))
    img_name = np.asarray(img_name)
    folder_name = np.asarray(folder_name)
    img_size = np.max(np.asarray(img_size), axis=0)
    # let img_size % 8 == 0
    img_size = np.array(np.ceil(img_size/8)*8,dtype=np.int32)
    return img_name, folder_name, img_size

def sub_load_data(data, img_size, aug): 
    img_name, dataset = data
    img = misc.imread(dataset+'images/'+img_name+'.bmp', mode='L')
    seg = misc.imread(dataset+'seg_labels/'+img_name+'.png', mode='L')
    try:
        ali = misc.imread(dataset+'ori_labels/'+img_name+'.bmp', mode='L')
    except:
        ali = np.zeros_like(img)
    mnt = np.array(mnt_reader(dataset+'mnt_labels/'+img_name+'.mnt'), dtype=float)
    if any(img.shape != img_size):
        # random pad mean values to reach required shape
        if np.random.rand()<aug:
            tra = np.int32(np.random.rand(2)*(np.array(img_size)-np.array(img.shape)))
        else:
            tra = np.int32(0.5*(np.array(img_size)-np.array(img.shape)))
        img_t = np.ones(img_size)*np.mean(img)
        seg_t = np.zeros(img_size)
        ali_t = np.ones(img_size)*np.mean(ali)
        img_t[tra[0]:tra[0]+img.shape[0],tra[1]:tra[1]+img.shape[1]] = img
        seg_t[tra[0]:tra[0]+img.shape[0],tra[1]:tra[1]+img.shape[1]] = seg
        ali_t[tra[0]:tra[0]+img.shape[0],tra[1]:tra[1]+img.shape[1]] = ali
        img = img_t
        seg = seg_t
        ali = ali_t
        mnt = mnt+np.array([tra[1],tra[0],0]) 
    if np.random.rand()<aug:
        # random rotation [0 - 360] & translation img_size / 4
        rot = np.random.rand() * 360
        tra = (np.random.rand(2)-0.5) / 2 * img_size 
        img = ndimage.rotate(img, rot, reshape=False, mode='reflect')
        img = ndimage.shift(img, tra, mode='reflect')
        seg = ndimage.rotate(seg, rot, reshape=False, mode='constant')
        seg = ndimage.shift(seg, tra, mode='constant')
        ali = ndimage.rotate(ali, rot, reshape=False, mode='reflect')
        ali = ndimage.shift(ali, tra, mode='reflect') 
        mnt_r = point_rot(mnt[:, :2], rot/180*np.pi, img.shape, img.shape)  
        mnt = np.column_stack((mnt_r+tra[[1, 0]], mnt[:, 2]-rot/180*np.pi))
    # only keep mnt that stay in pic & not on border
    mnt = mnt[(8<=mnt[:,0])*(mnt[:,0]<img_size[1]-8)*(8<=mnt[:, 1])*(mnt[:,1]<img_size[0]-8), :]
    return img, seg, ali, mnt   

def load_data(dataset, tra_ori_model, rand=False, aug=0.0, batch_size=1, sample_rate=None):
    if type(dataset[0]) == str:
        img_name, folder_name, img_size = get_maximum_img_size_and_names(dataset, sample_rate)
    else:
        img_name, folder_name, img_size = dataset
    if rand:
        rand_idx = np.arange(len(img_name))
        np.random.shuffle(rand_idx)
        img_name = img_name[rand_idx]
        folder_name = folder_name[rand_idx]
    if batch_size > 1 and use_multiprocessing==True:
        p = Pool(batch_size)        
    p_sub_load_data = partial(sub_load_data, img_size=img_size, aug=aug)
    for i in xrange(0,len(img_name), batch_size):
        have_alignment = np.ones([batch_size, 1, 1, 1])
        image = np.zeros((batch_size, img_size[0], img_size[1], 1))
        segment = np.zeros((batch_size, img_size[0], img_size[1], 1))
        alignment = np.zeros((batch_size, img_size[0], img_size[1], 1))
        minutiae_w = np.zeros((batch_size, img_size[0]/8, img_size[1]/8, 1))-1
        minutiae_h = np.zeros((batch_size, img_size[0]/8, img_size[1]/8, 1))-1
        minutiae_o = np.zeros((batch_size, img_size[0]/8, img_size[1]/8, 1))-1
        batch_name = [img_name[(i+j)%len(img_name)] for j in xrange(batch_size)]
        batch_f_name = [folder_name[(i+j)%len(img_name)] for j in xrange(batch_size)]
        if batch_size > 1 and use_multiprocessing==True:    
            results = p.map(p_sub_load_data, zip(batch_name, batch_f_name))
        else:
            results = map(p_sub_load_data, zip(batch_name, batch_f_name))
        for j in xrange(batch_size):
            img, seg, ali, mnt = results[j]
            if np.sum(ali) == 0:
                have_alignment[j, 0, 0, 0] = 0
            image[j, :, :, 0] = img / 255.0
            segment[j, :, :, 0] = seg / 255.0
            alignment[j, :, :, 0] = ali / 255.0
            minutiae_w[j, (mnt[:, 1]/8).astype(int), (mnt[:, 0]/8).astype(int), 0] = mnt[:, 0] % 8
            minutiae_h[j, (mnt[:, 1]/8).astype(int), (mnt[:, 0]/8).astype(int), 0] = mnt[:, 1] % 8
            minutiae_o[j, (mnt[:, 1]/8).astype(int), (mnt[:, 0]/8).astype(int), 0] = mnt[:, 2]
        # get seg
        label_seg = segment[:, ::8, ::8, :]
        label_seg[label_seg>0] = 1
        label_seg[label_seg<=0] = 0
        minutiae_seg = (minutiae_o!=-1).astype(float)
        # get ori & mnt
        orientation = tra_ori_model.predict(alignment)        
        orientation = orientation/np.pi*180+90
        orientation[orientation>=180.0] = 0.0 # orientation [0, 180)
        minutiae_o = minutiae_o/np.pi*180+90 # [90, 450)
        minutiae_o[minutiae_o>360] = minutiae_o[minutiae_o>360]-360 # to current coordinate system [0, 360)
        minutiae_ori_o = np.copy(minutiae_o) # copy one
        minutiae_ori_o[minutiae_ori_o>=180] = minutiae_ori_o[minutiae_ori_o>=180]-180 # for strong ori label [0,180)      
        # ori 2 gaussian
        gaussian_pdf = signal.gaussian(361, 3)
        y = np.reshape(np.arange(1, 180, 2), [1,1,1,-1])
        delta = np.array(np.abs(orientation - y), dtype=int)
        delta = np.minimum(delta, 180-delta)+180
        label_ori = gaussian_pdf[delta]
        # ori_o 2 gaussian
        delta = np.array(np.abs(minutiae_ori_o - y), dtype=int)
        delta = np.minimum(delta, 180-delta)+180
        label_ori_o = gaussian_pdf[delta] 
        # mnt_o 2 gaussian
        y = np.reshape(np.arange(1, 360, 2), [1,1,1,-1])
        delta = np.array(np.abs(minutiae_o - y), dtype=int)  
        delta = np.minimum(delta, 360-delta)+180
        label_mnt_o = gaussian_pdf[delta]         
        # w 2 gaussian
        gaussian_pdf = signal.gaussian(17, 2)
        y = np.reshape(np.arange(0, 8), [1,1,1,-1])
        delta = (minutiae_w-y+8).astype(int)
        label_mnt_w = gaussian_pdf[delta]
        # h 2 gaussian
        delta = (minutiae_h-y+8).astype(int)
        label_mnt_h = gaussian_pdf[delta]
        # mnt cls label -1:neg, 0:no care, 1:pos
        label_mnt_s = np.copy(minutiae_seg)
        label_mnt_s[label_mnt_s==0] = -1 # neg to -1
        label_mnt_s = (label_mnt_s+ndimage.maximum_filter(label_mnt_s, size=(1,3,3,1)))/2 # around 3*3 pos -> 0
        # apply segmentation
        label_ori = label_ori * label_seg * have_alignment
        label_ori_o = label_ori_o * minutiae_seg
        label_mnt_o = label_mnt_o * minutiae_seg
        label_mnt_w = label_mnt_w * minutiae_seg
        label_mnt_h = label_mnt_h * minutiae_seg
        yield image, label_ori, label_ori_o, label_seg, label_mnt_w, label_mnt_h, label_mnt_o, label_mnt_s, batch_name
    if batch_size > 1 and use_multiprocessing==True:
        p.close()
        p.join()
    return

def merge_mul(x):
    return reduce(lambda x,y:x*y, x)
def merge_sum(x):
    return reduce(lambda x,y:x+y, x)
def reduce_sum(x):
    return K.sum(x,axis=-1,keepdims=True) 
def merge_concat(x):
    return K.tf.concat(x,3)
def select_max(x):
    x = x / (K.max(x, axis=-1, keepdims=True)+K.epsilon())
    x = K.tf.where(K.tf.greater(x, 0.999), x, K.tf.zeros_like(x)) # select the biggest one
    x = x / (K.sum(x, axis=-1, keepdims=True)+K.epsilon()) # prevent two or more ori is selected
    return x  
def conv_bn(bottom, w_size, name, strides=(1,1), dilation_rate=(1,1)):
    top = Conv2D(w_size[0], (w_size[1],w_size[2]),
        kernel_regularizer=l2(5e-5),
        padding='same', 
        strides=strides,
        dilation_rate=dilation_rate,
        name='conv-'+name)(bottom)
    top = BatchNormalization(name='bn-'+name)(top)
    return top
def conv_bn_prelu(bottom, w_size, name, strides=(1,1), dilation_rate=(1,1)):
    if dilation_rate == (1,1):
        conv_type = 'conv'
    else:
        conv_type = 'atrousconv'
    top = Conv2D(w_size[0], (w_size[1],w_size[2]),
        kernel_regularizer=l2(5e-5),
        padding='same', 
        strides=strides,
        dilation_rate=dilation_rate,
        name=conv_type+name)(bottom)
    top = BatchNormalization(name='bn-'+name)(top)
    top=PReLU(alpha_initializer='zero', shared_axes=[1,2], name='prelu-'+name)(top)
    return top
def get_main_net(input_shape=(512,512,1), weights_path=None):
    img_input=Input(input_shape)
    bn_img=Lambda(img_normalization, name='img_norm')(img_input)
    # feature extraction VGG
    conv=conv_bn_prelu(bn_img, (64,3,3), '1_1') 
    conv=conv_bn_prelu(conv, (64,3,3), '1_2')
    conv=MaxPooling2D(pool_size=(2,2),strides=(2,2))(conv)

    conv=conv_bn_prelu(conv, (128,3,3), '2_1') 
    conv=conv_bn_prelu(conv, (128,3,3), '2_2') 
    conv=MaxPooling2D(pool_size=(2,2),strides=(2,2))(conv)

    conv=conv_bn_prelu(conv, (256,3,3), '3_1') 
    conv=conv_bn_prelu(conv, (256,3,3), '3_2') 
    conv=conv_bn_prelu(conv, (256,3,3), '3_3')   
    conv=MaxPooling2D(pool_size=(2,2),strides=(2,2))(conv)

    # multi-scale ASPP
    scale_1=conv_bn_prelu(conv, (256,3,3), '4_1', dilation_rate=(1,1))
    ori_1=conv_bn_prelu(scale_1, (128,1,1), 'ori_1_1')
    ori_1=Conv2D(90, (1,1), padding='same', name='ori_1_2')(ori_1)
    seg_1=conv_bn_prelu(scale_1, (128,1,1), 'seg_1_1')
    seg_1=Conv2D(1, (1,1), padding='same', name='seg_1_2')(seg_1)

    scale_2=conv_bn_prelu(conv, (256,3,3), '4_2', dilation_rate=(4,4))
    ori_2=conv_bn_prelu(scale_2, (128,1,1), 'ori_2_1')
    ori_2=Conv2D(90, (1,1), padding='same', name='ori_2_2')(ori_2)    
    seg_2=conv_bn_prelu(scale_2, (128,1,1), 'seg_2_1')
    seg_2=Conv2D(1, (1,1), padding='same', name='seg_2_2')(seg_2)

    scale_3=conv_bn_prelu(conv, (256,3,3), '4_3', dilation_rate=(8,8))
    ori_3=conv_bn_prelu(scale_3, (128,1,1), 'ori_3_1')
    ori_3=Conv2D(90, (1,1), padding='same', name='ori_3_2')(ori_3)  
    seg_3=conv_bn_prelu(scale_3, (128,1,1), 'seg_3_1')
    seg_3=Conv2D(1, (1,1), padding='same', name='seg_3_2')(seg_3)

    # sum fusion for ori
    ori_out=Lambda(merge_sum)([ori_1, ori_2, ori_3]) 
    ori_out_1=Activation('sigmoid', name='ori_out_1')(ori_out)
    ori_out_2=Activation('sigmoid', name='ori_out_2')(ori_out)

    # sum fusion for segmentation
    seg_out=Lambda(merge_sum)([seg_1, seg_2, seg_3])
    seg_out=Activation('sigmoid', name='seg_out')(seg_out)
    # ----------------------------------------------------------------------------
    # enhance part
    filters_cos, filters_sin = gabor_bank(stride=2, Lambda=8)
    filter_img_real = Conv2D(filters_cos.shape[3],(filters_cos.shape[0],filters_cos.shape[1]),
        weights=[filters_cos, np.zeros([filters_cos.shape[3]])], padding='same',
        name='enh_img_real_1')(img_input)
    filter_img_imag = Conv2D(filters_sin.shape[3],(filters_sin.shape[0],filters_sin.shape[1]),
        weights=[filters_sin, np.zeros([filters_sin.shape[3]])], padding='same',
        name='enh_img_imag_1')(img_input)
    ori_peak = Lambda(ori_highest_peak)(ori_out_1)
    ori_peak = Lambda(select_max)(ori_peak) # select max ori and set it to 1
    upsample_ori = UpSampling2D(size=(8,8))(ori_peak)
    seg_round = Activation('softsign')(seg_out)      
    upsample_seg = UpSampling2D(size=(8,8))(seg_round)
    mul_mask_real = Lambda(merge_mul)([filter_img_real, upsample_ori])
    enh_img_real = Lambda(reduce_sum, name='enh_img_real_2')(mul_mask_real)
    mul_mask_imag = Lambda(merge_mul)([filter_img_imag, upsample_ori])
    enh_img_imag = Lambda(reduce_sum, name='enh_img_imag_2')(mul_mask_imag)
    enh_img = Lambda(atan2, name='phase_img')([enh_img_imag, enh_img_real])
    enh_seg_img = Lambda(merge_concat, name='phase_seg_img')([enh_img, upsample_seg])
    # ----------------------------------------------------------------------------
    # mnt part
    mnt_conv=conv_bn_prelu(enh_seg_img, (64,9,9), 'mnt_1_1') 
    mnt_conv=MaxPooling2D(pool_size=(2,2),strides=(2,2))(mnt_conv)

    mnt_conv=conv_bn_prelu(mnt_conv, (128,5,5), 'mnt_2_1') 
    mnt_conv=MaxPooling2D(pool_size=(2,2),strides=(2,2))(mnt_conv)

    mnt_conv=conv_bn_prelu(mnt_conv, (256,3,3), 'mnt_3_1')  
    mnt_conv=MaxPooling2D(pool_size=(2,2),strides=(2,2))(mnt_conv)    

    mnt_o_1=Lambda(merge_concat)([mnt_conv, ori_out_1])
    mnt_o_2=conv_bn_prelu(mnt_o_1, (256,1,1), 'mnt_o_1_1')
    mnt_o_3=Conv2D(180, (1,1), padding='same', name='mnt_o_1_2')(mnt_o_2)
    mnt_o_out=Activation('sigmoid', name='mnt_o_out')(mnt_o_3)

    mnt_w_1=conv_bn_prelu(mnt_conv, (256,1,1), 'mnt_w_1_1')
    mnt_w_2=Conv2D(8, (1,1), padding='same', name='mnt_w_1_2')(mnt_w_1)
    mnt_w_out=Activation('sigmoid', name='mnt_w_out')(mnt_w_2)

    mnt_h_1=conv_bn_prelu(mnt_conv, (256,1,1), 'mnt_h_1_1')
    mnt_h_2=Conv2D(8, (1,1), padding='same', name='mnt_h_1_2')(mnt_h_1)
    mnt_h_out=Activation('sigmoid', name='mnt_h_out')(mnt_h_2) 

    mnt_s_1=conv_bn_prelu(mnt_conv, (256,1,1), 'mnt_s_1_1')
    mnt_s_2=Conv2D(1, (1,1), padding='same', name='mnt_s_1_2')(mnt_s_1)
    mnt_s_out=Activation('sigmoid', name='mnt_s_out')(mnt_s_2)

    if mode == 'deploy':
        model = Model(inputs=[img_input,], outputs=[enh_img_real, ori_out_1, ori_out_2, seg_out, mnt_o_out, mnt_w_out, mnt_h_out, mnt_s_out])
    else:
        model = Model(inputs=[img_input,], outputs=[ori_out_1, ori_out_2, seg_out, mnt_o_out, mnt_w_out, mnt_h_out, mnt_s_out])     
    if weights_path:
        model.load_weights(weights_path, by_name=True)
    return model   

kernal2angle = np.reshape(np.arange(1, 180, 2, dtype=float), [1,1,1,90])/90.*np.pi #2angle = angle*2
sin2angle, cos2angle = np.sin(kernal2angle), np.cos(kernal2angle)
def ori2angle(ori):
    sin2angle_ori = K.sum(ori*sin2angle, -1, keepdims=True)
    cos2angle_ori = K.sum(ori*cos2angle, -1, keepdims=True)
    modulus_ori = K.sqrt(K.square(sin2angle_ori)+K.square(cos2angle_ori))
    return sin2angle_ori, cos2angle_ori, modulus_ori

def ori_loss(y_true, y_pred, lamb=1.):
    # clip
    y_pred = K.tf.clip_by_value(y_pred, K.epsilon(), 1 - K.epsilon())
    # get ROI
    label_seg = K.sum(y_true, axis=-1, keepdims=True)
    label_seg = K.tf.cast(K.tf.greater(label_seg, 0), K.tf.float32) 
    # weighted cross entropy loss
    lamb_pos, lamb_neg = 1., 1. 
    logloss = lamb_pos*y_true*K.log(y_pred)+lamb_neg*(1-y_true)*K.log(1-y_pred)
    logloss = logloss*label_seg # apply ROI
    logloss = -K.sum(logloss) / (K.sum(label_seg) + K.epsilon())
    # coherence loss, nearby ori should be as near as possible
    mean_kernal = np.reshape(np.array([[1, 1, 1], [1, 1, 1], [1, 1, 1]], dtype=np.float32)/8, [3, 3, 1, 1])    
    sin2angle_ori, cos2angle_ori, modulus_ori = ori2angle(y_pred)
    sin2angle = K.conv2d(sin2angle_ori, mean_kernal, padding='same')
    cos2angle = K.conv2d(cos2angle_ori, mean_kernal, padding='same')
    modulus = K.conv2d(modulus_ori, mean_kernal, padding='same')
    coherence = K.sqrt(K.square(sin2angle) + K.square(cos2angle)) / (modulus + K.epsilon())
    coherenceloss = K.sum(label_seg) / (K.sum(coherence*label_seg) + K.epsilon()) - 1
    loss = logloss + lamb*coherenceloss
    return loss

def ori_o_loss(y_true, y_pred):
    # clip
    y_pred = K.tf.clip_by_value(y_pred, K.epsilon(), 1 - K.epsilon())
    # get ROI
    label_seg = K.sum(y_true, axis=-1, keepdims=True)
    label_seg = K.tf.cast(K.tf.greater(label_seg, 0), K.tf.float32) 
    # weighted cross entropy loss
    lamb_pos, lamb_neg= 1., 1. 
    logloss = lamb_pos*y_true*K.log(y_pred)+lamb_neg*(1-y_true)*K.log(1-y_pred)
    logloss = logloss*label_seg # apply ROI
    logloss = -K.sum(logloss) / (K.sum(label_seg) + K.epsilon())
    return logloss

def seg_loss(y_true, y_pred, lamb=1.):
    # clip
    y_pred = K.tf.clip_by_value(y_pred, K.epsilon(), 1 - K.epsilon())
    # weighted cross entropy loss
    total_elements = K.sum(K.tf.ones_like(y_true))
    label_pos = K.tf.cast(K.tf.greater(y_true, 0.0), K.tf.float32)   
    lamb_pos = 0.5 * total_elements / K.sum(label_pos)
    lamb_neg = 1 / (2 - 1/lamb_pos)
    logloss = lamb_pos*y_true*K.log(y_pred)+lamb_neg*(1-y_true)*K.log(1-y_pred)
    logloss = -K.mean(K.sum(logloss, axis=-1))
    # smooth loss
    smooth_kernal = np.reshape(np.array([[-1, -1, -1], [-1, 8, -1], [-1, -1, -1]], dtype=np.float32)/8, [3, 3, 1, 1])
    smoothloss = K.mean(K.abs(K.conv2d(y_pred, smooth_kernal)))
    loss = logloss + lamb*smoothloss
    return loss

def mnt_s_loss(y_true, y_pred):
    # clip
    y_pred = K.tf.clip_by_value(y_pred, K.epsilon(), 1 - K.epsilon())
    # get ROI
    label_seg = K.tf.cast(K.tf.not_equal(y_true, 0.0), K.tf.float32) 
    y_true = K.tf.where(K.tf.less(y_true,0.0), K.tf.zeros_like(y_true), y_true) # set -1 -> 0
    # weighted cross entropy loss       
    total_elements = K.sum(label_seg) + K.epsilon()  
    lamb_pos, lamb_neg = 10., .5
    logloss = lamb_pos*y_true*K.log(y_pred)+lamb_neg*(1-y_true)*K.log(1-y_pred)
    # apply ROI
    logloss = logloss*label_seg
    logloss = -K.sum(logloss) / total_elements
    return logloss    

# find highest peak using gaussian
def ori_highest_peak(y_pred, length=180):
	 # y_pred = tf.convert_to_tensor(y_pred, np.float32)
    glabel = gausslabel(length=length,stride=2).astype(np.float32)
    ori_gau = K.conv2d(y_pred,glabel,padding='same')
    return ori_gau

def ori_acc_delta_k(y_true, y_pred, k=10, max_delta=180):
    # get ROI
    label_seg = K.sum(y_true, axis=-1)
    label_seg = K.tf.cast(K.tf.greater(label_seg, 0), K.tf.float32) 
    # get pred angle    
    angle = K.cast(K.argmax(ori_highest_peak(y_pred, max_delta), axis=-1), dtype=K.tf.float32)*2.0+1.0
    # get gt angle
    angle_t = K.cast(K.argmax(y_true, axis=-1), dtype=K.tf.float32)*2.0+1.0
    # get delta
    angle_delta = K.abs(angle_t - angle)
    acc = K.tf.less_equal(K.minimum(angle_delta, max_delta-angle_delta), k)
    acc = K.cast(acc, dtype=K.tf.float32)
    # apply ROI
    acc = acc*label_seg
    acc = K.sum(acc) / (K.sum(label_seg)+K.epsilon())
    return acc
def ori_acc_delta_10(y_true, y_pred):
    return ori_acc_delta_k(y_true, y_pred, 10)
def ori_acc_delta_20(y_true, y_pred):
    return ori_acc_delta_k(y_true, y_pred, 20)
def mnt_acc_delta_10(y_true, y_pred):
    return ori_acc_delta_k(y_true, y_pred, 10, 360)
def mnt_acc_delta_20(y_true, y_pred):
    return ori_acc_delta_k(y_true, y_pred, 20, 360)    

def seg_acc_pos(y_true, y_pred):
    y_true = K.tf.where(K.tf.less(y_true,0.0), K.tf.zeros_like(y_true), y_true)
    acc = K.cast(K.equal(y_true, K.round(y_pred)), dtype=K.tf.float32)
    acc = K.sum(acc * y_true) / (K.sum(y_true)+K.epsilon())
    return acc    
def seg_acc_neg(y_true, y_pred):
    y_true = K.tf.where(K.tf.less(y_true,0.0), K.tf.zeros_like(y_true), y_true)
    acc = K.cast(K.equal(y_true, K.round(y_pred)), dtype=K.tf.float32)
    acc = K.sum(acc * (1-y_true)) / (K.sum(1-y_true)+K.epsilon())
    return acc
def seg_acc_all(y_true, y_pred):
    y_true = K.tf.where(K.tf.less(y_true,0.0), K.tf.zeros_like(y_true), y_true)
    return K.mean(K.equal(y_true, K.round(y_pred)))  

def mnt_mean_delta(y_true, y_pred):
    # get ROI
    label_seg = K.sum(y_true, axis=-1)
    label_seg = K.tf.cast(K.tf.greater(label_seg, 0), K.tf.float32) 
    # get pred pos    
    pos = K.cast(K.argmax(y_pred, axis=-1), dtype=K.tf.float32)
    # get gt pos
    pos_t = K.cast(K.argmax(y_true, axis=-1), dtype=K.tf.float32)
    # get delta
    pos_delta = K.abs(pos_t - pos)
    # apply ROI
    pos_delta = pos_delta*label_seg
    mean_delta = K.sum(pos_delta) / (K.sum(label_seg)+K.epsilon())
    return mean_delta

def train(input_shape=(512,512,1)):
    img_name, folder_name, img_size = get_maximum_img_size_and_names(train_set, train_sample_rate)  
    main_net_model = get_main_net((img_size[0],img_size[1],1), pretrain)
    plot_model(main_net_model, to_file=output_dir+'/model.png',show_shapes=True)
    adam = Adam(lr=0.0001, beta_1=0.9, beta_2=0.999, epsilon=1e-08)    
    main_net_model.compile(optimizer=adam, 
        loss={'ori_out_1':ori_loss, 'ori_out_2':ori_o_loss, 'seg_out':seg_loss, 
                'mnt_o_out':ori_o_loss, 'mnt_w_out':ori_o_loss, 'mnt_h_out':ori_o_loss, 'mnt_s_out':mnt_s_loss}, 
        loss_weights={'ori_out_1':.1, 'ori_out_2':.1, 'seg_out':10., 
                'mnt_w_out':.5, 'mnt_h_out':.5, 'mnt_o_out':.5,'mnt_s_out':200.},
        metrics={'ori_out_1':[ori_acc_delta_10,],
                 'ori_out_2':[ori_acc_delta_10,],
                 'seg_out':[seg_acc_pos, seg_acc_neg, seg_acc_all],
                 'mnt_o_out':[mnt_acc_delta_10,],
                 'mnt_w_out':[mnt_mean_delta,],
                 'mnt_h_out':[mnt_mean_delta,],
                 'mnt_s_out':[seg_acc_pos, seg_acc_neg, seg_acc_all]})
    for epoch in range(100):
        for i, train in enumerate(load_data((img_name, folder_name, img_size), tra_ori_model, rand=True, aug=0.7, batch_size=batch_size)):
            loss = main_net_model.train_on_batch(train[0], 
                {'ori_out_1':train[1], 'ori_out_2':train[2], 'seg_out':train[3],
                'mnt_w_out':train[4], 'mnt_h_out':train[5], 'mnt_o_out':train[6], 'mnt_s_out':train[7]})  
            if i%(20/batch_size) == 0:
                logging.info("epoch=%d, step=%d", epoch, i)
                logging.info("%s", " ".join(["%s:%.4f\n"%(x) for x in zip(main_net_model.metrics_names, loss)]))
            if i%(10000/batch_size) == (10000/batch_size)-1:
                # test every 10000 pics
                outdir = "%s/%03d_%05d/"%(output_dir, epoch, i)
                re_mkdir(outdir)
                savedir = "%s%s"%(outdir, str(epoch)+'_'+str(i))
                main_net_model.save_weights(savedir, True)
                for folder in test_set:
                    test([folder,], savedir, outdir, test_num=10, draw=False)
    return

# currently can only produce one each time
def label2mnt(mnt_s_out, mnt_w_out, mnt_h_out, mnt_o_out, thresh=0.5):
    mnt_s_out = np.squeeze(mnt_s_out)
    mnt_w_out = np.squeeze(mnt_w_out)
    mnt_h_out = np.squeeze(mnt_h_out)
    mnt_o_out = np.squeeze(mnt_o_out)
    assert len(mnt_s_out.shape)==2 and len(mnt_w_out.shape)==3 and len(mnt_h_out.shape)==3 and len(mnt_o_out.shape)==3 
    # get cls results
    mnt_sparse = sparse.coo_matrix(mnt_s_out>thresh)
    mnt_list = np.array(zip(mnt_sparse.row, mnt_sparse.col), dtype=np.int32)
    if mnt_list.shape[0] == 0:
        return np.zeros((0, 4))
    # get regression results
    mnt_w_out = np.argmax(mnt_w_out, axis=-1)
    mnt_h_out = np.argmax(mnt_h_out, axis=-1)
    mnt_o_out = np.argmax(mnt_o_out, axis=-1) # TODO: use ori_highest_peak(np version)
    # get final mnt
    mnt_final = np.zeros((len(mnt_list), 4))
    mnt_final[:, 0] = mnt_sparse.col*8 + mnt_w_out[mnt_list[:,0], mnt_list[:,1]]
    mnt_final[:, 1] = mnt_sparse.row*8 + mnt_h_out[mnt_list[:,0], mnt_list[:,1]]
    mnt_final[:, 2] = (mnt_o_out[mnt_list[:,0], mnt_list[:,1]]*2-89.)/180*np.pi
    mnt_final[mnt_final[:, 2]<0.0, 2] = mnt_final[mnt_final[:, 2]<0.0, 2]+2*np.pi
    mnt_final[:, 3] = mnt_s_out[mnt_list[:,0], mnt_list[:, 1]]
    return mnt_final
def test(test_set, model, outdir, test_num=10, draw=True):
    logging.info("Testing %s:"%(test_set))
    img_name, folder_name, img_size = get_maximum_img_size_and_names(test_set)  
    main_net_model = get_main_net((img_size[0],img_size[1],1), model)
    nonsense = SGD(lr=0.0, momentum=0.0, decay=0.0, nesterov=False)    
    main_net_model.compile(optimizer=nonsense,
        loss={'ori_out_1':ori_loss, 'ori_out_2':ori_o_loss, 'seg_out':seg_loss, 
                'mnt_o_out':ori_o_loss, 'mnt_w_out':ori_o_loss, 'mnt_h_out':ori_o_loss, 'mnt_s_out':mnt_s_loss}, 
        loss_weights={'ori_out_1':.1, 'ori_out_2':.1, 'seg_out':10., 
                'mnt_w_out':.5, 'mnt_h_out':.5, 'mnt_o_out':.5,'mnt_s_out':200.},        
        metrics={'ori_out_1':[ori_acc_delta_10,ori_acc_delta_20],
                 'ori_out_2':[ori_acc_delta_10,ori_acc_delta_20],
                 'seg_out':[seg_acc_pos, seg_acc_neg, seg_acc_all],
                 'mnt_o_out':[mnt_acc_delta_10,mnt_acc_delta_20],
                 'mnt_w_out':[mnt_mean_delta,],
                 'mnt_h_out':[mnt_mean_delta,],
                 'mnt_s_out':[seg_acc_pos, seg_acc_neg, seg_acc_all]})
    ave_loss, ave_prf_nms = [], []
    for j, test in enumerate(load_data((img_name, folder_name, img_size), tra_ori_model, rand=False, aug=0.0, batch_size=1)):      
        if j < test_num:
            logging.info("%d / %d: %s"%(j+1, len(img_name), img_name[j]))    
            ori_out_1, ori_out_2, seg_out, mnt_o_out, mnt_w_out, mnt_h_out, mnt_s_out  = main_net_model.predict(test[0])
            metrics = main_net_model.train_on_batch(test[0], 
                {'ori_out_1':test[1], 'ori_out_2':test[2], 'seg_out':test[3],
                'mnt_w_out':test[4], 'mnt_h_out':test[5], 'mnt_o_out':test[6], 'mnt_s_out':test[7]})  
            ave_loss.append(metrics)
            logging.info("%s", " ".join(["%s:%.4f\n"%(x) for x in zip(main_net_model.metrics_names, metrics)]))
            mnt_gt = label2mnt(test[7], test[4], test[5], test[6])
            mnt_s_out = mnt_s_out * test[3]
            mnt = label2mnt(mnt_s_out, mnt_w_out, mnt_h_out, mnt_o_out, thresh=0.5)
            mnt_nms = nms(mnt)
            p, r, f, l, o = mnt_P_R_F(mnt_gt, mnt_nms)
            logging.info("After_nms:\nprecision: %f\nrecall: %f\nf1-measure: %f\nlocation_dis: %f\norientation_delta:%f\n----------------\n"%(
                p, r, f, l, o))
            ave_prf_nms.append([p, r, f, l, o])            
            if draw:                         
                angval = sess.run(ori_highest_peak(ori_out_1))                           
                angval = (np.argmax(angval, axis=-1)*2-90)/180.*np.pi
                draw_ori_on_img(test[0], angval, seg_out, "%s%s_ori.png"%(outdir, test[8][0]))
                draw_minutiae(test[0], mnt_nms[:,:3], "%s%s_mnt.png"%(outdir, test[8][0]))
                draw_minutiae(test[0], mnt_gt[:,:3], "%s%s_mnt_gt.png"%(outdir, test[8][0]))
        else:
            break
    logging.info("Average testing results:")
    ave_loss = np.mean(np.array(ave_loss), 0)
    ave_prf_nms = np.mean(np.array(ave_prf_nms), 0)
    logging.info("\n%s\n", " ".join(["%s:%.4f\n"%(x) for x in zip(main_net_model.metrics_names, ave_loss)]))
    logging.info("After_nms:\nprecision: %f\nrecall: %f\nf1-measure: %f\nlocation_dis: %f\norientation_delta:%f\n----------------\n"%(
                    ave_prf_nms[0],ave_prf_nms[1],ave_prf_nms[2],ave_prf_nms[3],ave_prf_nms[4]))     
    return

def deploy(deploy_set, set_name=None):
    if set_name is None:
        set_name = deploy_set.split('/')[-2]
    mkdir(output_dir+'/'+set_name+'/')
    logging.info("Predicting %s:"%(set_name)) 
    _, img_name = get_files_in_folder(deploy_set, '.bmp')
    if len(img_name) == 0:
        deploy_set = deploy_set+'images/'
        _, img_name = get_files_in_folder(deploy_set, '.bmp')
    img_size = misc.imread(deploy_set+img_name[0]+'.bmp', mode='L').shape
    img_size = np.array(img_size, dtype=np.int32)/8*8      
    main_net_model = get_main_net((img_size[0],img_size[1],1), pretrain)
    _, img_name = get_files_in_folder(deploy_set, '.bmp')
    time_c = []
    for i in xrange(0,len(img_name)):
        logging.info("%s %d / %d: %s"%(set_name, i+1, len(img_name), img_name[i]))
        time_start = time()    
        image = misc.imread(deploy_set+img_name[i]+'.bmp', mode='L') / 255.0
        image = image[:img_size[0],:img_size[1]]      
        image = np.reshape(image,[1, image.shape[0], image.shape[1], 1])
        enhance_img, ori_out_1, ori_out_2, seg_out, mnt_o_out, mnt_w_out, mnt_h_out, mnt_s_out = main_net_model.predict(image) 
        time_afterconv = time()
        round_seg = np.round(np.squeeze(seg_out))
        kernel = cv2.getStructuringElement(cv2.MORPH_RECT,(5, 5))
        seg_out = cv2.morphologyEx(round_seg, cv2.MORPH_OPEN, kernel)
        mnt = label2mnt(np.squeeze(mnt_s_out)*np.round(np.squeeze(seg_out)), mnt_w_out, mnt_h_out, mnt_o_out, thresh=0.5)
        mnt_nms = nms(mnt)
        ori = sess.run(ori_highest_peak(ori_out_1))                           
        ori = (np.argmax(ori, axis=-1)*2-90)/180.*np.pi  
        time_afterpost = time()
        mnt_writer(mnt_nms, img_name[i], img_size, "%s/%s/%s.mnt"%(output_dir, set_name, img_name[i]))        
        draw_ori_on_img(image, ori, np.ones_like(seg_out), "%s/%s/%s_ori.png"%(output_dir, set_name, img_name[i]))        
        draw_minutiae(image, mnt_nms[:,:3], "%s/%s/%s_mnt.png"%(output_dir, set_name, img_name[i]))
        misc.imsave("%s/%s/%s_enh.png"%(output_dir, set_name, img_name[i]), np.squeeze(enhance_img)*ndimage.zoom(np.round(np.squeeze(seg_out)), [8,8], order=0))
        misc.imsave("%s/%s/%s_seg.png"%(output_dir, set_name, img_name[i]), ndimage.zoom(np.round(np.squeeze(seg_out)), [8,8], order=0)) 
        io.savemat("%s/%s/%s.mat"%(output_dir, set_name, img_name[i]), {'orientation':ori, 'orientation_distribution_map':ori_out_1})
        time_afterdraw = time()
        time_c.append([time_afterconv-time_start, time_afterpost-time_afterconv, time_afterdraw-time_afterpost])
        logging.info("load+conv: %.3fs, seg-postpro+nms: %.3f, draw: %.3f"%(time_c[-1][0],time_c[-1][1],time_c[-1][2]))
    time_c = np.mean(np.array(time_c),axis=0)
    logging.info("Average: load+conv: %.3fs, oir-select+seg-post+nms: %.3f, draw: %.3f"%(time_c[0],time_c[1],time_c[2]))
    return  

def main():
    if mode == 'train':
        train()
    elif mode == 'test':        
        for folder in test_set:
            test([folder,], pretrain, output_dir+"/", test_num=258, draw=False) 
    elif mode == 'deploy':
        for i, folder in enumerate(deploy_set):
            deploy(folder, str(i))
    else:
        pass

if __name__ =='__main__':
    main()
# Out:
# Using TensorFlow backend.
# Predicting 0:
# /usr/local/lib/python2.7/dist-packages/ipykernel_launcher.py:656: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
# 0 1 / 959: s10_5
# /usr/local/lib/python2.7/dist-packages/ipykernel_launcher.py:664: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
# utils.py:194: MatplotlibDeprecationWarning: pyplot.hold is deprecated.
#     Future behavior will be consistent with the long-time default:
#     plot commands add elements without first clearing the
#     Axes and/or Figure.
#   plt.hold(True)
# /usr/local/lib/python2.7/dist-packages/matplotlib/__init__.py:910: MatplotlibDeprecationWarning: axes.hold is deprecated. Please remove it from your matplotlibrc and/or style files.
#   mplDeprecation)
# /usr/local/lib/python2.7/dist-packages/matplotlib/rcsetup.py:156: MatplotlibDeprecationWarning: axes.hold is deprecated, will be removed in 3.0
#   mplDeprecation)
# utils.py:173: MatplotlibDeprecationWarning: pyplot.hold is deprecated.
#     Future behavior will be consistent with the long-time default:
#     plot commands add elements without first clearing the
#     Axes and/or Figure.
#   plt.hold(True)
# /usr/local/lib/python2.7/dist-packages/ipykernel_launcher.py:680: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
# /usr/local/lib/python2.7/dist-packages/ipykernel_launcher.py:681: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
# load+conv: 0.867s, seg-postpro+nms: 0.136, draw: 1.123
# 0 2 / 959: s10_4
# load+conv: 1.125s, seg-postpro+nms: 0.117, draw: 1.242
# 0 3 / 959: s113_2
# load+conv: 1.059s, seg-postpro+nms: 0.089, draw: 1.128
# 0 4 / 959: s10_2
# load+conv: 1.135s, seg-postpro+nms: 0.124, draw: 1.336
# 0 5 / 959: s113_1
# load+conv: 1.122s, seg-postpro+nms: 0.098, draw: 1.121
# 0 6 / 959: s10_3
# load+conv: 1.053s, seg-postpro+nms: 0.121, draw: 1.081
# 0 7 / 959: s10_6
# load+conv: 1.077s, seg-postpro+nms: 0.095, draw: 1.043
# 0 8 / 959: s10_1
# load+conv: 1.069s, seg-postpro+nms: 0.110, draw: 1.277
# 0 9 / 959: s114_1
# load+conv: 2.129s, seg-postpro+nms: 0.067, draw: 1.004
# 0 10 / 959: s113_6
# load+conv: 1.109s, seg-postpro+nms: 0.085, draw: 1.049
# 0 11 / 959: s114_3
# load+conv: 1.105s, seg-postpro+nms: 0.074, draw: 1.066
# 0 12 / 959: s114_4
# load+conv: 1.040s, seg-postpro+nms: 0.066, draw: 1.352
# 0 13 / 959: s115_3
# load+conv: 1.041s, seg-postpro+nms: 0.085, draw: 1.028
# 0 14 / 959: s115_2
# load+conv: 1.076s, seg-postpro+nms: 0.072, draw: 1.019
# 0 15 / 959: s114_6
# load+conv: 1.085s, seg-postpro+nms: 0.074, draw: 1.032
# 0 16 / 959: s113_3
# load+conv: 1.116s, seg-postpro+nms: 0.090, draw: 1.048
# 0 17 / 959: s114_5
# load+conv: 1.086s, seg-postpro+nms: 0.069, draw: 1.424
# 0 18 / 959: s115_1
# load+conv: 1.086s, seg-postpro+nms: 0.075, draw: 1.021
# 0 19 / 959: s115_4
# load+conv: 1.092s, seg-postpro+nms: 0.089, draw: 1.034
# 0 20 / 959: s113_5
# load+conv: 1.055s, seg-postpro+nms: 0.093, draw: 1.038
# 0 21 / 959: s114_2
# load+conv: 1.025s, seg-postpro+nms: 0.074, draw: 1.010
# 0 22 / 959: s115_5
# load+conv: 1.125s, seg-postpro+nms: 0.077, draw: 1.039
# 0 23 / 959: s113_4
# load+conv: 1.055s, seg-postpro+nms: 0.092, draw: 1.027
# 0 24 / 959: s115_6
# load+conv: 1.088s, seg-postpro+nms: 0.080, draw: 1.583
# 0 25 / 959: s118_1
# load+conv: 1.079s, seg-postpro+nms: 0.087, draw: 1.059
# 0 26 / 959: s118_5
# load+conv: 1.109s, seg-postpro+nms: 0.087, draw: 1.060
# 0 27 / 959: s116_5
# load+conv: 1.084s, seg-postpro+nms: 0.078, draw: 1.058
# 0 28 / 959: s118_2
# load+conv: 1.109s, seg-postpro+nms: 0.085, draw: 1.045
# 0 29 / 959: s118_3
# load+conv: 1.061s, seg-postpro+nms: 0.085, draw: 1.053
# 0 30 / 959: s118_6
# load+conv: 1.174s, seg-postpro+nms: 0.096, draw: 1.076
# 0 31 / 959: s116_2
# load+conv: 1.079s, seg-postpro+nms: 0.076, draw: 1.042
# 0 32 / 959: s117_1
# load+conv: 1.103s, seg-postpro+nms: 0.104, draw: 1.774
# 0 33 / 959: s117_4
# load+conv: 1.097s, seg-postpro+nms: 0.108, draw: 1.061
# 0 34 / 959: s116_6
# load+conv: 1.052s, seg-postpro+nms: 0.074, draw: 1.042
# 0 35 / 959: s117_5
# load+conv: 1.136s, seg-postpro+nms: 0.107, draw: 1.075
# 0 36 / 959: s117_6
# load+conv: 1.160s, seg-postpro+nms: 0.106, draw: 1.054
# 0 37 / 959: s116_4
# load+conv: 1.113s, seg-postpro+nms: 0.075, draw: 1.050
# 0 38 / 959: s118_4
# load+conv: 1.124s, seg-postpro+nms: 0.093, draw: 1.046
# 0 39 / 959: s117_2
# load+conv: 1.071s, seg-postpro+nms: 0.110, draw: 1.062
# 0 40 / 959: s116_3
# load+conv: 1.088s, seg-postpro+nms: 0.075, draw: 1.038
# 0 41 / 959: s116_1
# load+conv: 1.075s, seg-postpro+nms: 0.077, draw: 1.025
# 0 42 / 959: s117_3
# load+conv: 1.144s, seg-postpro+nms: 0.100, draw: 1.041
# 0 43 / 959: s120_1
# load+conv: 1.147s, seg-postpro+nms: 0.095, draw: 1.942
# 0 44 / 959: s119_3
# load+conv: 1.059s, seg-postpro+nms: 0.104, draw: 1.053
# 0 45 / 959: s120_2
# load+conv: 1.100s, seg-postpro+nms: 0.104, draw: 1.052
# 0 46 / 959: s11_5
# load+conv: 1.114s, seg-postpro+nms: 0.125, draw: 1.059
# 0 47 / 959: s119_6
# load+conv: 1.085s, seg-postpro+nms: 0.097, draw: 1.102
# 0 48 / 959: s11_3
# load+conv: 1.141s, seg-postpro+nms: 0.134, draw: 1.108
# 0 49 / 959: s119_2
# load+conv: 1.118s, seg-postpro+nms: 0.107, draw: 1.104
# 0 50 / 959: s119_1
# load+conv: 1.194s, seg-postpro+nms: 0.101, draw: 1.107
# 0 51 / 959: s11_6
# load+conv: 1.188s, seg-postpro+nms: 0.124, draw: 1.140
# 0 52 / 959: s11_4
# load+conv: 1.122s, seg-postpro+nms: 0.131, draw: 1.123
# 0 53 / 959: s119_4
# load+conv: 1.098s, seg-postpro+nms: 0.102, draw: 1.126
# 0 54 / 959: s120_4
# load+conv: 1.050s, seg-postpro+nms: 0.095, draw: 1.085
# 0 55 / 959: s119_5
# load+conv: 1.138s, seg-postpro+nms: 0.093, draw: 1.091
# 0 56 / 959: s120_3
# load+conv: 1.147s, seg-postpro+nms: 0.099, draw: 2.261
# 0 57 / 959: s120_5
# load+conv: 1.158s, seg-postpro+nms: 0.092, draw: 1.107
# 0 58 / 959: s11_1
# load+conv: 1.099s, seg-postpro+nms: 0.135, draw: 1.145
# 0 59 / 959: s11_2
# load+conv: 1.151s, seg-postpro+nms: 0.130, draw: 1.108
# 0 60 / 959: s122_3
# load+conv: 1.070s, seg-postpro+nms: 0.096, draw: 1.066
# 0 61 / 959: s120_6
# load+conv: 1.132s, seg-postpro+nms: 0.074, draw: 1.048
# 0 62 / 959: s121_2
# load+conv: 1.112s, seg-postpro+nms: 0.092, draw: 1.054
# 0 63 / 959: s121_4
# load+conv: 1.125s, seg-postpro+nms: 0.104, draw: 1.065
# 0 64 / 959: s122_1
# load+conv: 1.089s, seg-postpro+nms: 0.095, draw: 1.081
# 0 65 / 959: s121_3
# load+conv: 1.118s, seg-postpro+nms: 0.097, draw: 1.071
# 0 66 / 959: s121_5
# load+conv: 1.090s, seg-postpro+nms: 0.091, draw: 1.072
# 0 67 / 959: s122_6
# load+conv: 1.076s, seg-postpro+nms: 0.095, draw: 1.050
# 0 68 / 959: s121_1
# load+conv: 1.098s, seg-postpro+nms: 0.088, draw: 1.049
# 0 69 / 959: s122_2
# load+conv: 1.125s, seg-postpro+nms: 0.094, draw: 1.078
# 0 70 / 959: s121_6
# load+conv: 1.054s, seg-postpro+nms: 0.094, draw: 1.038
# 0 71 / 959: s122_5
# load+conv: 1.101s, seg-postpro+nms: 0.097, draw: 1.046
# 0 72 / 959: s122_4
# load+conv: 1.080s, seg-postpro+nms: 0.095, draw: 2.538
# 0 73 / 959: s124_6
# load+conv: 1.096s, seg-postpro+nms: 0.094, draw: 1.039
# 0 74 / 959: s125_1
# load+conv: 1.075s, seg-postpro+nms: 0.084, draw: 1.045
# 0 75 / 959: s124_3
# load+conv: 1.071s, seg-postpro+nms: 0.097, draw: 1.021
# 0 76 / 959: s123_4
# load+conv: 1.054s, seg-postpro+nms: 0.077, draw: 1.006
# 0 77 / 959: s124_2
# load+conv: 1.132s, seg-postpro+nms: 0.105, draw: 1.061
# 0 78 / 959: s125_2
# load+conv: 1.089s, seg-postpro+nms: 0.088, draw: 1.024
# 0 79 / 959: s123_3
# load+conv: 1.148s, seg-postpro+nms: 0.079, draw: 1.042
# 0 80 / 959: s124_5
# load+conv: 1.123s, seg-postpro+nms: 0.098, draw: 1.033
# 0 81 / 959: s123_5
# load+conv: 1.117s, seg-postpro+nms: 0.076, draw: 0.994
# 0 82 / 959: s124_4
# load+conv: 1.133s, seg-postpro+nms: 0.110, draw: 1.109
# 0 83 / 959: s125_3
# load+conv: 1.116s, seg-postpro+nms: 0.078, draw: 1.060
# 0 84 / 959: s123_2
# load+conv: 1.129s, seg-postpro+nms: 0.078, draw: 1.060
# 0 85 / 959: s124_1
# load+conv: 1.187s, seg-postpro+nms: 0.109, draw: 1.113
# 0 86 / 959: s123_1
# load+conv: 1.160s, seg-postpro+nms: 0.082, draw: 1.073
# 0 87 / 959: s123_6
# load+conv: 1.169s, seg-postpro+nms: 0.077, draw: 1.079
# 0 88 / 959: s125_4
# load+conv: 1.123s, seg-postpro+nms: 0.087, draw: 1.071
# 0 89 / 959: s126_5
# load+conv: 1.128s, seg-postpro+nms: 0.091, draw: 1.085
# 0 90 / 959: s127_6
# load+conv: 1.155s, seg-postpro+nms: 0.080, draw: 1.084
# 0 91 / 959: s126_3
# load+conv: 1.097s, seg-postpro+nms: 0.092, draw: 1.115
# 0 92 / 959: s128_4
# load+conv: 1.137s, seg-postpro+nms: 0.079, draw: 2.972
# 0 93 / 959: s126_4
# load+conv: 1.146s, seg-postpro+nms: 0.097, draw: 1.116
# 0 94 / 959: s127_5
# load+conv: 1.128s, seg-postpro+nms: 0.080, draw: 1.064
# 0 95 / 959: s127_2
# load+conv: 1.135s, seg-postpro+nms: 0.082, draw: 1.088
# 0 96 / 959: s127_4
# load+conv: 1.140s, seg-postpro+nms: 0.080, draw: 1.069
# 0 97 / 959: s125_5
# load+conv: 1.110s, seg-postpro+nms: 0.088, draw: 1.094
# 0 98 / 959: s126_2
# load+conv: 1.185s, seg-postpro+nms: 0.095, draw: 1.128
# 0 99 / 959: s127_3
# load+conv: 1.170s, seg-postpro+nms: 0.080, draw: 1.068
# 0 100 / 959: s128_3
# load+conv: 1.133s, seg-postpro+nms: 0.107, draw: 1.042
# 0 101 / 959: s128_1
# load+conv: 1.191s, seg-postpro+nms: 0.076, draw: 1.068
# 0 102 / 959: s126_1
# load+conv: 1.116s, seg-postpro+nms: 0.094, draw: 1.090
# 0 103 / 959: s127_1
# load+conv: 1.115s, seg-postpro+nms: 0.081, draw: 1.064
# 0 104 / 959: s128_2
# load+conv: 1.121s, seg-postpro+nms: 0.075, draw: 1.035
# 0 105 / 959: s126_6
# load+conv: 1.118s, seg-postpro+nms: 0.098, draw: 1.080
# 0 106 / 959: s125_6
# load+conv: 1.127s, seg-postpro+nms: 0.087, draw: 1.099
# 0 107 / 959: s12_3
# load+conv: 1.140s, seg-postpro+nms: 0.114, draw: 1.088
# 0 108 / 959: s12_4
# load+conv: 1.148s, seg-postpro+nms: 0.108, draw: 1.098
# 0 109 / 959: s12_6
# load+conv: 1.143s, seg-postpro+nms: 0.117, draw: 1.114
# 0 110 / 959: s129_1
# load+conv: 1.198s, seg-postpro+nms: 0.102, draw: 1.092
# 0 111 / 959: s129_6
# load+conv: 1.443s, seg-postpro+nms: 0.101, draw: 1.121
# 0 112 / 959: s130_3
# load+conv: 1.158s, seg-postpro+nms: 0.090, draw: 1.079
# 0 113 / 959: s128_5
# load+conv: 1.143s, seg-postpro+nms: 0.082, draw: 1.063
# 0 114 / 959: s129_2
# load+conv: 1.126s, seg-postpro+nms: 0.107, draw: 1.121
# 0 115 / 959: s129_3
# load+conv: 1.109s, seg-postpro+nms: 0.103, draw: 1.084
# 0 116 / 959: s130_1
# load+conv: 1.156s, seg-postpro+nms: 0.093, draw: 1.103
# 0 117 / 959: s12_1
# load+conv: 1.141s, seg-postpro+nms: 0.127, draw: 1.107
# 0 118 / 959: s12_2
# load+conv: 1.114s, seg-postpro+nms: 0.118, draw: 3.538
# 0 119 / 959: s129_4
# load+conv: 1.134s, seg-postpro+nms: 0.102, draw: 1.117
# 0 120 / 959: s128_6
# load+conv: 1.169s, seg-postpro+nms: 0.079, draw: 1.043
# 0 121 / 959: s129_5
# load+conv: 1.122s, seg-postpro+nms: 0.107, draw: 1.097
# 0 122 / 959: s12_5
# load+conv: 1.185s, seg-postpro+nms: 0.114, draw: 1.100
# 0 123 / 959: s130_2
# load+conv: 1.134s, seg-postpro+nms: 0.105, draw: 1.091
# 0 124 / 959: s131_6
# load+conv: 1.118s, seg-postpro+nms: 0.109, draw: 1.133
# 0 125 / 959: s131_2
# load+conv: 1.178s, seg-postpro+nms: 0.111, draw: 1.098
# 0 126 / 959: s130_5
# load+conv: 1.174s, seg-postpro+nms: 0.089, draw: 1.073
# 0 127 / 959: s132_4
# load+conv: 1.169s, seg-postpro+nms: 0.105, draw: 1.138
# 0 128 / 959: s131_3
# load+conv: 1.171s, seg-postpro+nms: 0.102, draw: 1.082
# 0 129 / 959: s130_6
# load+conv: 1.109s, seg-postpro+nms: 0.090, draw: 1.082
# 0 130 / 959: s132_2
# load+conv: 1.117s, seg-postpro+nms: 0.103, draw: 1.094
# 0 131 / 959: s132_3
# load+conv: 1.105s, seg-postpro+nms: 0.095, draw: 1.099
# 0 132 / 959: s132_1
# load+conv: 1.184s, seg-postpro+nms: 0.092, draw: 1.099
# 0 133 / 959: s132_5
# load+conv: 1.138s, seg-postpro+nms: 0.108, draw: 1.085
# 0 134 / 959: s131_4
# load+conv: 1.134s, seg-postpro+nms: 0.101, draw: 1.091
# 0 135 / 959: s132_6
# load+conv: 1.177s, seg-postpro+nms: 0.099, draw: 1.104
# 0 136 / 959: s133_1
# load+conv: 1.168s, seg-postpro+nms: 0.093, draw: 1.078
# 0 137 / 959: s130_4
# load+conv: 1.160s, seg-postpro+nms: 0.091, draw: 1.107
# 0 138 / 959: s131_1
# load+conv: 1.141s, seg-postpro+nms: 0.108, draw: 1.095
# 0 139 / 959: s131_5
# load+conv: 1.123s, seg-postpro+nms: 0.105, draw: 1.086
# 0 140 / 959: s134_5
# load+conv: 1.146s, seg-postpro+nms: 0.100, draw: 1.133
# 0 141 / 959: s135_1
# load+conv: 1.151s, seg-postpro+nms: 0.098, draw: 1.112
# 0 142 / 959: s133_2
# load+conv: 1.198s, seg-postpro+nms: 0.091, draw: 1.072
# 0 143 / 959: s133_4
# load+conv: 1.289s, seg-postpro+nms: 0.098, draw: 1.073
# 0 144 / 959: s133_3
# load+conv: 1.185s, seg-postpro+nms: 0.098, draw: 1.090
# 0 145 / 959: s134_2
# load+conv: 1.130s, seg-postpro+nms: 0.098, draw: 1.103
# 0 146 / 959: s136_2
# load+conv: 1.127s, seg-postpro+nms: 0.104, draw: 1.082
# 0 147 / 959: s135_5
# load+conv: 1.231s, seg-postpro+nms: 0.101, draw: 1.092
# 0 148 / 959: s133_5
# load+conv: 1.340s, seg-postpro+nms: 0.098, draw: 1.080
# 0 149 / 959: s134_6
# load+conv: 1.144s, seg-postpro+nms: 0.102, draw: 4.176
# 0 150 / 959: s133_6
# load+conv: 1.142s, seg-postpro+nms: 0.098, draw: 1.092
# 0 151 / 959: s135_4
# load+conv: 1.145s, seg-postpro+nms: 0.098, draw: 1.090
# 0 152 / 959: s134_3
# load+conv: 1.143s, seg-postpro+nms: 0.102, draw: 1.084
# 0 153 / 959: s134_4
# load+conv: 1.120s, seg-postpro+nms: 0.104, draw: 1.086
# 0 154 / 959: s134_1
# load+conv: 1.123s, seg-postpro+nms: 0.093, draw: 1.074
# 0 155 / 959: s135_3
# load+conv: 1.128s, seg-postpro+nms: 0.095, draw: 1.079
# 0 156 / 959: s136_1
# load+conv: 1.142s, seg-postpro+nms: 0.097, draw: 1.122
# 0 157 / 959: s135_2
# load+conv: 1.196s, seg-postpro+nms: 0.110, draw: 1.090
# 0 158 / 959: s135_6
# load+conv: 1.161s, seg-postpro+nms: 0.107, draw: 1.129
# 0 159 / 959: s145_1
# load+conv: 1.146s, seg-postpro+nms: 0.147, draw: 1.121
# 0 160 / 959: s13_6
# load+conv: 1.145s, seg-postpro+nms: 0.127, draw: 1.106
# 0 161 / 959: s145_2
# load+conv: 1.238s, seg-postpro+nms: 0.139, draw: 1.108
# 0 162 / 959: s13_1
# load+conv: 1.174s, seg-postpro+nms: 0.115, draw: 1.095
# 0 163 / 959: s145_5
# load+conv: 1.159s, seg-postpro+nms: 0.149, draw: 1.151
# 0 164 / 959: s136_6
# load+conv: 1.197s, seg-postpro+nms: 0.108, draw: 1.101
# 0 165 / 959: s145_4
# load+conv: 1.158s, seg-postpro+nms: 0.142, draw: 1.120
# 0 166 / 959: s145_3
# load+conv: 1.121s, seg-postpro+nms: 0.150, draw: 1.180
# 0 167 / 959: s13_2
# load+conv: 1.142s, seg-postpro+nms: 0.113, draw: 1.103
# 0 168 / 959: s136_3
# load+conv: 1.168s, seg-postpro+nms: 0.103, draw: 1.112
# 0 169 / 959: s136_4
# load+conv: 1.166s, seg-postpro+nms: 0.104, draw: 1.093
# 0 170 / 959: s13_4
# load+conv: 1.164s, seg-postpro+nms: 0.128, draw: 1.115
# 0 171 / 959: s146_2
# load+conv: 1.163s, seg-postpro+nms: 0.144, draw: 1.139
# 0 172 / 959: s145_6
# load+conv: 1.227s, seg-postpro+nms: 0.125, draw: 1.112
# 0 173 / 959: s146_1
# load+conv: 1.166s, seg-postpro+nms: 0.140, draw: 1.111
# 0 174 / 959: s136_5
# load+conv: 1.170s, seg-postpro+nms: 0.108, draw: 1.114
# 0 175 / 959: s146_3
# load+conv: 1.185s, seg-postpro+nms: 0.136, draw: 1.106
# 0 176 / 959: s13_3
# load+conv: 1.133s, seg-postpro+nms: 0.117, draw: 1.120
# 0 177 / 959: s13_5
# load+conv: 1.120s, seg-postpro+nms: 0.122, draw: 1.117
# 0 178 / 959: s147_6
# load+conv: 1.126s, seg-postpro+nms: 0.136, draw: 1.117
# 0 179 / 959: s148_6
# load+conv: 1.149s, seg-postpro+nms: 0.130, draw: 1.121
# 0 180 / 959: s148_2
# load+conv: 1.106s, seg-postpro+nms: 0.112, draw: 1.035
# 0 181 / 959: s148_5
# load+conv: 1.139s, seg-postpro+nms: 0.096, draw: 1.053
# 0 182 / 959: s149_1
# load+conv: 1.067s, seg-postpro+nms: 0.122, draw: 1.082
# 0 183 / 959: s147_4
# load+conv: 1.166s, seg-postpro+nms: 0.125, draw: 1.063
# 0 184 / 959: s149_2
# load+conv: 1.143s, seg-postpro+nms: 0.123, draw: 1.080
# 0 185 / 959: s148_1
# load+conv: 1.127s, seg-postpro+nms: 0.119, draw: 1.062
# 0 186 / 959: s147_5
# load+conv: 1.099s, seg-postpro+nms: 0.134, draw: 1.091
# 0 187 / 959: s146_4
# load+conv: 1.107s, seg-postpro+nms: 0.129, draw: 1.076
# 0 188 / 959: s146_6
# load+conv: 1.089s, seg-postpro+nms: 0.135, draw: 5.000
# 0 189 / 959: s148_4
# load+conv: 1.121s, seg-postpro+nms: 0.136, draw: 1.097
# 0 190 / 959: s148_3
# load+conv: 1.141s, seg-postpro+nms: 0.107, draw: 1.048
# 0 191 / 959: s147_2
# load+conv: 1.073s, seg-postpro+nms: 0.137, draw: 1.062
# 0 192 / 959: s146_5
# load+conv: 1.117s, seg-postpro+nms: 0.116, draw: 1.053
# 0 193 / 959: s147_3
# load+conv: 1.086s, seg-postpro+nms: 0.146, draw: 1.063
# 0 194 / 959: s147_1
# load+conv: 1.073s, seg-postpro+nms: 0.116, draw: 1.059
# 0 195 / 959: s149_4
# load+conv: 1.119s, seg-postpro+nms: 0.118, draw: 1.082
# 0 196 / 959: s151_1
# load+conv: 1.059s, seg-postpro+nms: 0.092, draw: 1.038
# 0 197 / 959: s149_3
# load+conv: 1.088s, seg-postpro+nms: 0.108, draw: 1.076
# 0 198 / 959: s151_3
# load+conv: 1.111s, seg-postpro+nms: 0.094, draw: 1.040
# 0 199 / 959: s151_5
# load+conv: 1.091s, seg-postpro+nms: 0.096, draw: 1.035
# 0 200 / 959: s14_1
# load+conv: 1.065s, seg-postpro+nms: 0.132, draw: 1.089
# 0 201 / 959: s151_2
# load+conv: 1.089s, seg-postpro+nms: 0.095, draw: 1.040
# 0 202 / 959: s14_5
# load+conv: 1.115s, seg-postpro+nms: 0.118, draw: 1.088
# 0 203 / 959: s150_5
# load+conv: 1.085s, seg-postpro+nms: 0.104, draw: 1.049
# 0 204 / 959: s150_3
# load+conv: 1.191s, seg-postpro+nms: 0.109, draw: 1.050
# 0 205 / 959: s150_4
# load+conv: 1.077s, seg-postpro+nms: 0.107, draw: 1.046
# 0 206 / 959: s14_6
# load+conv: 1.117s, seg-postpro+nms: 0.144, draw: 1.068
# 0 207 / 959: s149_6
# load+conv: 1.307s, seg-postpro+nms: 0.123, draw: 1.085
# 0 208 / 959: s14_3
# load+conv: 1.076s, seg-postpro+nms: 0.132, draw: 1.063
# 0 209 / 959: s149_5
# load+conv: 1.168s, seg-postpro+nms: 0.123, draw: 1.058
# 0 210 / 959: s150_2
# load+conv: 1.084s, seg-postpro+nms: 0.110, draw: 1.077
# 0 211 / 959: s14_2
# load+conv: 1.070s, seg-postpro+nms: 0.123, draw: 1.064
# 0 212 / 959: s151_4
# load+conv: 1.100s, seg-postpro+nms: 0.095, draw: 1.045
# 0 213 / 959: s150_1
# load+conv: 1.070s, seg-postpro+nms: 0.121, draw: 1.077
# 0 214 / 959: s14_4
# load+conv: 1.054s, seg-postpro+nms: 0.113, draw: 1.062
# 0 215 / 959: s150_6
# load+conv: 1.084s, seg-postpro+nms: 0.104, draw: 1.059
# 0 216 / 959: s161_6
# load+conv: 1.113s, seg-postpro+nms: 0.104, draw: 1.060
# 0 217 / 959: s15_4
# load+conv: 1.060s, seg-postpro+nms: 0.130, draw: 1.066
# 0 218 / 959: s152_5
# load+conv: 1.123s, seg-postpro+nms: 0.105, draw: 1.063
# 0 219 / 959: s152_6
# load+conv: 1.181s, seg-postpro+nms: 0.095, draw: 1.026
# 0 220 / 959: s15_1
# load+conv: 1.065s, seg-postpro+nms: 0.138, draw: 1.070
# 0 221 / 959: s161_2
# load+conv: 1.141s, seg-postpro+nms: 0.104, draw: 1.062
# 0 222 / 959: s152_4
# load+conv: 1.162s, seg-postpro+nms: 0.099, draw: 1.039
# 0 223 / 959: s161_5
# load+conv: 1.112s, seg-postpro+nms: 0.107, draw: 1.045
# 0 224 / 959: s152_1
# load+conv: 1.112s, seg-postpro+nms: 0.098, draw: 1.050
# 0 225 / 959: s152_3
# load+conv: 1.087s, seg-postpro+nms: 0.101, draw: 1.057
# 0 226 / 959: s152_2
# load+conv: 1.096s, seg-postpro+nms: 0.103, draw: 1.057
# 0 227 / 959: s15_5
# load+conv: 1.113s, seg-postpro+nms: 0.132, draw: 1.068
# 0 228 / 959: s15_6
# load+conv: 1.091s, seg-postpro+nms: 0.135, draw: 1.069
# 0 229 / 959: s161_4
# load+conv: 1.062s, seg-postpro+nms: 0.112, draw: 1.058
# 0 230 / 959: s161_3
# load+conv: 1.066s, seg-postpro+nms: 0.109, draw: 1.047
# 0 231 / 959: s161_1
# load+conv: 1.076s, seg-postpro+nms: 0.107, draw: 1.056
# 0 232 / 959: s15_2
# load+conv: 1.076s, seg-postpro+nms: 0.142, draw: 1.069
# 0 233 / 959: s15_3
# load+conv: 1.096s, seg-postpro+nms: 0.134, draw: 1.072
# 0 234 / 959: s151_6
# load+conv: 1.077s, seg-postpro+nms: 0.099, draw: 1.028
# 0 235 / 959: s162_2
# load+conv: 1.060s, seg-postpro+nms: 0.107, draw: 1.042
# 0 236 / 959: s162_3
# load+conv: 1.105s, seg-postpro+nms: 0.108, draw: 1.072
# 0 237 / 959: s164_3
# load+conv: 1.059s, seg-postpro+nms: 0.100, draw: 1.030
# 0 238 / 959: s163_1
# load+conv: 1.065s, seg-postpro+nms: 0.094, draw: 5.993
# 0 239 / 959: s162_4
# load+conv: 1.086s, seg-postpro+nms: 0.104, draw: 1.042
# 0 240 / 959: s164_5
# load+conv: 1.066s, seg-postpro+nms: 0.098, draw: 1.031
# 0 241 / 959: s164_2
# load+conv: 1.065s, seg-postpro+nms: 0.099, draw: 1.062
# 0 242 / 959: s164_4
# load+conv: 1.086s, seg-postpro+nms: 0.103, draw: 1.031
# 0 243 / 959: s164_6
# load+conv: 1.105s, seg-postpro+nms: 0.099, draw: 1.039
# 0 244 / 959: s165_1
# load+conv: 1.151s, seg-postpro+nms: 0.101, draw: 1.048
# 0 245 / 959: s163_6
# load+conv: 1.092s, seg-postpro+nms: 0.098, draw: 1.017
# 0 246 / 959: s164_1
# load+conv: 1.099s, seg-postpro+nms: 0.101, draw: 1.069
# 0 247 / 959: s165_2
# load+conv: 1.081s, seg-postpro+nms: 0.102, draw: 1.043
# 0 248 / 959: s163_5
# load+conv: 1.083s, seg-postpro+nms: 0.098, draw: 1.042
# 0 249 / 959: s162_5
# load+conv: 1.082s, seg-postpro+nms: 0.103, draw: 1.038
# 0 250 / 959: s163_2
# load+conv: 1.079s, seg-postpro+nms: 0.099, draw: 1.038
# 0 251 / 959: s162_6
# load+conv: 1.090s, seg-postpro+nms: 0.106, draw: 1.036
# 0 252 / 959: s162_1
# load+conv: 1.104s, seg-postpro+nms: 0.112, draw: 1.070
# 0 253 / 959: s163_3
# load+conv: 1.093s, seg-postpro+nms: 0.095, draw: 1.029
# 0 254 / 959: s163_4
# load+conv: 1.065s, seg-postpro+nms: 0.102, draw: 1.057
# 0 255 / 959: s167_5
# load+conv: 1.194s, seg-postpro+nms: 0.094, draw: 1.019
# 0 256 / 959: s168_3
# load+conv: 1.081s, seg-postpro+nms: 0.102, draw: 1.029
# 0 257 / 959: s166_1
# load+conv: 1.058s, seg-postpro+nms: 0.098, draw: 1.052
# 0 258 / 959: s168_5
# load+conv: 1.086s, seg-postpro+nms: 0.101, draw: 1.038
# 0 259 / 959: s168_1
# load+conv: 1.087s, seg-postpro+nms: 0.099, draw: 1.033
# 0 260 / 959: s167_6
# load+conv: 1.093s, seg-postpro+nms: 0.095, draw: 1.016
# 0 261 / 959: s167_2
# load+conv: 1.121s, seg-postpro+nms: 0.102, draw: 1.030
# 0 262 / 959: s166_5
# load+conv: 1.101s, seg-postpro+nms: 0.101, draw: 1.038
# 0 263 / 959: s165_3
# load+conv: 1.119s, seg-postpro+nms: 0.105, draw: 1.048
# 0 264 / 959: s168_4
# load+conv: 1.084s, seg-postpro+nms: 0.105, draw: 1.038
# 0 265 / 959: s166_3
# load+conv: 1.093s, seg-postpro+nms: 0.100, draw: 1.035
# 0 266 / 959: s165_6
# load+conv: 1.050s, seg-postpro+nms: 0.112, draw: 1.138
# 0 267 / 959: s167_1
# load+conv: 1.068s, seg-postpro+nms: 0.096, draw: 1.038
# 0 268 / 959: s168_2
# load+conv: 1.074s, seg-postpro+nms: 0.101, draw: 1.044
# 0 269 / 959: s168_6
# load+conv: 1.104s, seg-postpro+nms: 0.104, draw: 1.029
# 0 270 / 959: s166_6
# load+conv: 1.119s, seg-postpro+nms: 0.104, draw: 1.046
# 0 271 / 959: s165_4
# load+conv: 1.065s, seg-postpro+nms: 0.111, draw: 1.067
# 0 272 / 959: s166_2
# load+conv: 1.070s, seg-postpro+nms: 0.101, draw: 1.052
# 0 273 / 959: s165_5
# load+conv: 1.094s, seg-postpro+nms: 0.104, draw: 1.040
# 0 274 / 959: s167_4
# load+conv: 1.119s, seg-postpro+nms: 0.099, draw: 1.033
# 0 275 / 959: s167_3
# load+conv: 1.095s, seg-postpro+nms: 0.099, draw: 1.044
# 0 276 / 959: s166_4
# load+conv: 1.063s, seg-postpro+nms: 0.100, draw: 1.023
# 0 277 / 959: s169_3
# load+conv: 1.085s, seg-postpro+nms: 0.103, draw: 1.029
# 0 278 / 959: s169_1
# load+conv: 1.095s, seg-postpro+nms: 0.108, draw: 1.076
# 0 279 / 959: s169_4
# load+conv: 1.069s, seg-postpro+nms: 0.103, draw: 1.020
# 0 280 / 959: s169_5
# load+conv: 1.073s, seg-postpro+nms: 0.101, draw: 1.046
# 0 281 / 959: s16_1
# load+conv: 1.059s, seg-postpro+nms: 0.144, draw: 1.062
# 0 282 / 959: s16_2
# load+conv: 1.067s, seg-postpro+nms: 0.141, draw: 1.053
# 0 283 / 959: s16_4
# load+conv: 1.180s, seg-postpro+nms: 0.148, draw: 1.080
# 0 284 / 959: s16_5
# load+conv: 1.072s, seg-postpro+nms: 0.144, draw: 1.055
# 0 285 / 959: s16_3
# load+conv: 1.063s, seg-postpro+nms: 0.159, draw: 1.091
# 0 286 / 959: s169_2
# load+conv: 1.090s, seg-postpro+nms: 0.103, draw: 1.013
# 0 287 / 959: s169_6
# load+conv: 1.093s, seg-postpro+nms: 0.101, draw: 1.038
# 0 288 / 959: s16_6
# load+conv: 1.083s, seg-postpro+nms: 0.138, draw: 1.081
# 0 289 / 959: s170_5
# load+conv: 1.069s, seg-postpro+nms: 0.105, draw: 1.043
# 0 290 / 959: s170_3
# load+conv: 1.123s, seg-postpro+nms: 0.109, draw: 1.045
# 0 291 / 959: s172_3
# load+conv: 1.111s, seg-postpro+nms: 0.103, draw: 1.014
# 0 292 / 959: s172_5
# load+conv: 1.240s, seg-postpro+nms: 0.099, draw: 1.009
# 0 293 / 959: s170_4
# load+conv: 1.109s, seg-postpro+nms: 0.111, draw: 1.061
# 0 294 / 959: s172_2
# load+conv: 1.069s, seg-postpro+nms: 0.102, draw: 0.999
# 0 295 / 959: s171_6
# load+conv: 1.110s, seg-postpro+nms: 0.101, draw: 1.007
# 0 296 / 959: s172_4
# load+conv: 1.068s, seg-postpro+nms: 0.101, draw: 1.027
# 0 297 / 959: s172_6
# load+conv: 1.059s, seg-postpro+nms: 0.099, draw: 1.004
# 0 298 / 959: s171_4
# load+conv: 1.067s, seg-postpro+nms: 0.105, draw: 1.041
# 0 299 / 959: s171_3
# load+conv: 1.081s, seg-postpro+nms: 0.108, draw: 1.043
# 0 300 / 959: s171_2
# load+conv: 1.090s, seg-postpro+nms: 0.108, draw: 7.283
# 0 301 / 959: s171_1
# load+conv: 1.070s, seg-postpro+nms: 0.109, draw: 1.028
# 0 302 / 959: s170_1
# load+conv: 1.055s, seg-postpro+nms: 0.119, draw: 1.055
# 0 303 / 959: s173_1
# load+conv: 1.063s, seg-postpro+nms: 0.111, draw: 1.063
# 0 304 / 959: s170_2
# load+conv: 1.078s, seg-postpro+nms: 0.115, draw: 1.038
# 0 305 / 959: s170_6
# load+conv: 1.078s, seg-postpro+nms: 0.112, draw: 1.030
# 0 306 / 959: s172_1
# load+conv: 1.101s, seg-postpro+nms: 0.107, draw: 1.035
# 0 307 / 959: s171_5
# load+conv: 1.103s, seg-postpro+nms: 0.100, draw: 1.016
# 0 308 / 959: s175_4
# load+conv: 1.112s, seg-postpro+nms: 0.101, draw: 1.023
# 0 309 / 959: s176_6
# load+conv: 1.072s, seg-postpro+nms: 0.109, draw: 1.060
# 0 310 / 959: s175_1
# load+conv: 1.070s, seg-postpro+nms: 0.104, draw: 1.024
# 0 311 / 959: s175_5
# load+conv: 1.070s, seg-postpro+nms: 0.108, draw: 1.051
# 0 312 / 959: s173_4
# load+conv: 1.083s, seg-postpro+nms: 0.111, draw: 1.043
# 0 313 / 959: s174_5
# load+conv: 1.151s, seg-postpro+nms: 0.107, draw: 1.064
# 0 314 / 959: s173_6
# load+conv: 1.174s, seg-postpro+nms: 0.124, draw: 1.128
# 0 315 / 959: s175_2
# load+conv: 1.107s, seg-postpro+nms: 0.100, draw: 1.090
# 0 316 / 959: s174_1
# load+conv: 1.087s, seg-postpro+nms: 0.110, draw: 1.095
# 0 317 / 959: s176_3
# load+conv: 1.107s, seg-postpro+nms: 0.118, draw: 1.069
# 0 318 / 959: s173_3
# load+conv: 1.112s, seg-postpro+nms: 0.133, draw: 1.082
# 0 319 / 959: s17_1
# load+conv: 1.126s, seg-postpro+nms: 0.130, draw: 1.109
# 0 320 / 959: s173_2
# load+conv: 1.148s, seg-postpro+nms: 0.119, draw: 1.083
# 0 321 / 959: s173_5
# load+conv: 1.078s, seg-postpro+nms: 0.115, draw: 1.054
# 0 322 / 959: s175_3
# load+conv: 1.091s, seg-postpro+nms: 0.109, draw: 1.065
# 0 323 / 959: s175_6
# load+conv: 1.073s, seg-postpro+nms: 0.108, draw: 1.053
# 0 324 / 959: s176_4
# load+conv: 1.089s, seg-postpro+nms: 0.107, draw: 1.068
# 0 325 / 959: s174_2
# load+conv: 1.112s, seg-postpro+nms: 0.108, draw: 1.054
# 0 326 / 959: s176_1
# load+conv: 1.087s, seg-postpro+nms: 0.107, draw: 1.044
# 0 327 / 959: s174_4
# load+conv: 1.101s, seg-postpro+nms: 0.105, draw: 1.047
# 0 328 / 959: s174_6
# load+conv: 1.075s, seg-postpro+nms: 0.107, draw: 1.032
# 0 329 / 959: s176_2
# load+conv: 1.088s, seg-postpro+nms: 0.111, draw: 1.043
# 0 330 / 959: s174_3
# load+conv: 1.085s, seg-postpro+nms: 0.113, draw: 1.044
# 0 331 / 959: s176_5
# load+conv: 1.076s, seg-postpro+nms: 0.107, draw: 1.029
# 0 332 / 959: s17_6
# load+conv: 1.077s, seg-postpro+nms: 0.126, draw: 1.088
# 0 333 / 959: s17_5
# load+conv: 1.074s, seg-postpro+nms: 0.125, draw: 1.064
# 0 334 / 959: s18_4
# load+conv: 1.071s, seg-postpro+nms: 0.111, draw: 1.056
# 0 335 / 959: s193_2
# load+conv: 1.104s, seg-postpro+nms: 0.119, draw: 1.069
# 0 336 / 959: s194_6
# load+conv: 1.093s, seg-postpro+nms: 0.115, draw: 1.039
# 0 337 / 959: s193_6
# load+conv: 1.097s, seg-postpro+nms: 0.124, draw: 1.078
# 0 338 / 959: s17_2
# load+conv: 1.078s, seg-postpro+nms: 0.127, draw: 1.059
# 0 339 / 959: s194_4
# load+conv: 1.069s, seg-postpro+nms: 0.113, draw: 1.018
# 0 340 / 959: s194_3
# load+conv: 1.058s, seg-postpro+nms: 0.107, draw: 1.030
# 0 341 / 959: s194_2
# load+conv: 1.048s, seg-postpro+nms: 0.106, draw: 1.009
# 0 342 / 959: s17_4
# load+conv: 1.140s, seg-postpro+nms: 0.123, draw: 1.065
# 0 343 / 959: s18_5
# load+conv: 1.063s, seg-postpro+nms: 0.111, draw: 1.026
# 0 344 / 959: s17_3
# load+conv: 1.073s, seg-postpro+nms: 0.126, draw: 1.045
# 0 345 / 959: s18_3
# load+conv: 1.055s, seg-postpro+nms: 0.114, draw: 1.050
# 0 346 / 959: s193_3
# load+conv: 1.060s, seg-postpro+nms: 0.113, draw: 1.022
# 0 347 / 959: s194_1
# load+conv: 1.097s, seg-postpro+nms: 0.106, draw: 1.013
# 0 348 / 959: s18_2
# load+conv: 1.102s, seg-postpro+nms: 0.109, draw: 1.015
# 0 349 / 959: s193_1
# load+conv: 1.043s, seg-postpro+nms: 0.112, draw: 1.013
# 0 350 / 959: s18_1
# load+conv: 1.070s, seg-postpro+nms: 0.111, draw: 1.040
# 0 351 / 959: s18_6
# load+conv: 1.070s, seg-postpro+nms: 0.107, draw: 1.001
# 0 352 / 959: s193_4
# load+conv: 1.090s, seg-postpro+nms: 0.127, draw: 1.058
# 0 353 / 959: s193_5
# load+conv: 1.051s, seg-postpro+nms: 0.119, draw: 1.042
# 0 354 / 959: s194_5
# load+conv: 1.053s, seg-postpro+nms: 0.115, draw: 1.004
# 0 355 / 959: s197_2
# load+conv: 1.062s, seg-postpro+nms: 0.104, draw: 1.026
# 0 356 / 959: s197_1
# load+conv: 1.043s, seg-postpro+nms: 0.104, draw: 0.990
# 0 357 / 959: s198_1
# load+conv: 1.080s, seg-postpro+nms: 0.109, draw: 0.998
# 0 358 / 959: s196_6
# load+conv: 1.482s, seg-postpro+nms: 0.103, draw: 1.067
# 0 359 / 959: s195_4
# load+conv: 1.112s, seg-postpro+nms: 0.116, draw: 1.056
# 0 360 / 959: s197_5
# load+conv: 1.112s, seg-postpro+nms: 0.112, draw: 1.066
# 0 361 / 959: s195_5
# load+conv: 1.122s, seg-postpro+nms: 0.113, draw: 1.052
# 0 362 / 959: s197_3
# load+conv: 1.148s, seg-postpro+nms: 0.111, draw: 1.053
# 0 363 / 959: s196_2
# load+conv: 1.114s, seg-postpro+nms: 0.111, draw: 1.079
# 0 364 / 959: s198_2
# load+conv: 1.110s, seg-postpro+nms: 0.113, draw: 1.068
# 0 365 / 959: s197_6
# load+conv: 1.191s, seg-postpro+nms: 0.112, draw: 1.055
# 0 366 / 959: s197_4
# load+conv: 1.130s, seg-postpro+nms: 0.115, draw: 1.078
# 0 367 / 959: s196_4
# load+conv: 1.110s, seg-postpro+nms: 0.115, draw: 1.063
# 0 368 / 959: s196_1
# load+conv: 1.087s, seg-postpro+nms: 0.112, draw: 1.059
# 0 369 / 959: s196_3
# load+conv: 1.111s, seg-postpro+nms: 0.111, draw: 1.065
# 0 370 / 959: s195_2
# load+conv: 1.191s, seg-postpro+nms: 0.115, draw: 1.070
# 0 371 / 959: s195_3
# load+conv: 1.162s, seg-postpro+nms: 0.116, draw: 1.123
# 0 372 / 959: s196_5
# load+conv: 1.159s, seg-postpro+nms: 0.110, draw: 1.047
# 0 373 / 959: s195_1
# load+conv: 1.121s, seg-postpro+nms: 0.119, draw: 1.079
# 0 374 / 959: s195_6
# load+conv: 1.125s, seg-postpro+nms: 0.119, draw: 1.081
# 0 375 / 959: s1_3
# load+conv: 1.114s, seg-postpro+nms: 0.134, draw: 1.093
# 0 376 / 959: s19_5
# load+conv: 1.151s, seg-postpro+nms: 0.119, draw: 1.106
# 0 377 / 959: s1_6
# load+conv: 1.112s, seg-postpro+nms: 0.147, draw: 1.100
# 0 378 / 959: s200_1
# load+conv: 1.182s, seg-postpro+nms: 0.112, draw: 9.021
# 0 379 / 959: s1_4
# load+conv: 1.136s, seg-postpro+nms: 0.165, draw: 1.093
# 0 380 / 959: s200_2
# load+conv: 1.111s, seg-postpro+nms: 0.117, draw: 1.055
# 0 381 / 959: s1_2
# load+conv: 1.124s, seg-postpro+nms: 0.133, draw: 1.100
# 0 382 / 959: s199_5
# load+conv: 1.141s, seg-postpro+nms: 0.112, draw: 1.051
# 0 383 / 959: s198_3
# load+conv: 1.119s, seg-postpro+nms: 0.115, draw: 1.070
# 0 384 / 959: s1_5
# load+conv: 1.118s, seg-postpro+nms: 0.152, draw: 1.122
# 0 385 / 959: s199_1
# load+conv: 1.129s, seg-postpro+nms: 0.115, draw: 1.049
# 0 386 / 959: s19_1
# load+conv: 1.128s, seg-postpro+nms: 0.120, draw: 1.082
# 0 387 / 959: s19_3
# load+conv: 1.139s, seg-postpro+nms: 0.122, draw: 1.057
# 0 388 / 959: s198_6
# load+conv: 1.120s, seg-postpro+nms: 0.115, draw: 1.065
# 0 389 / 959: s1_1
# load+conv: 1.154s, seg-postpro+nms: 0.138, draw: 1.119
# 0 390 / 959: s19_2
# load+conv: 1.153s, seg-postpro+nms: 0.131, draw: 1.086
# 0 391 / 959: s19_4
# load+conv: 1.113s, seg-postpro+nms: 0.130, draw: 1.063
# 0 392 / 959: s199_4
# load+conv: 1.117s, seg-postpro+nms: 0.114, draw: 1.056
# 0 393 / 959: s199_6
# load+conv: 1.093s, seg-postpro+nms: 0.114, draw: 1.058
# 0 394 / 959: s198_5
# load+conv: 1.109s, seg-postpro+nms: 0.114, draw: 1.075
# 0 395 / 959: s199_2
# load+conv: 1.120s, seg-postpro+nms: 0.115, draw: 1.061
# 0 396 / 959: s19_6
# load+conv: 1.097s, seg-postpro+nms: 0.124, draw: 1.079
# 0 397 / 959: s199_3
# load+conv: 1.096s, seg-postpro+nms: 0.119, draw: 1.085
# 0 398 / 959: s198_4
# load+conv: 1.117s, seg-postpro+nms: 0.122, draw: 1.054
# 0 399 / 959: s200_6
# load+conv: 1.191s, seg-postpro+nms: 0.116, draw: 1.072
# 0 400 / 959: s202_2
# load+conv: 1.115s, seg-postpro+nms: 0.151, draw: 1.114
# 0 401 / 959: s200_5
# load+conv: 1.138s, seg-postpro+nms: 0.118, draw: 1.065
# 0 402 / 959: s202_4
# load+conv: 1.141s, seg-postpro+nms: 0.150, draw: 1.133
# 0 403 / 959: s200_3
# load+conv: 1.116s, seg-postpro+nms: 0.121, draw: 1.060
# 0 404 / 959: s201_6
# load+conv: 1.110s, seg-postpro+nms: 0.203, draw: 1.130
# 0 405 / 959: s201_1
# load+conv: 1.062s, seg-postpro+nms: 0.195, draw: 1.069
# 0 406 / 959: s201_3
# load+conv: 1.085s, seg-postpro+nms: 0.187, draw: 1.075
# 0 407 / 959: s201_4
# load+conv: 1.078s, seg-postpro+nms: 0.191, draw: 1.075
# 0 408 / 959: s201_2
# load+conv: 1.075s, seg-postpro+nms: 0.192, draw: 1.083
# 0 409 / 959: s202_1
# load+conv: 1.077s, seg-postpro+nms: 0.145, draw: 1.069
# 0 410 / 959: s202_3
# load+conv: 1.052s, seg-postpro+nms: 0.149, draw: 1.066
# 0 411 / 959: s200_4
# load+conv: 1.077s, seg-postpro+nms: 0.115, draw: 1.026
# 0 412 / 959: s201_5
# load+conv: 1.075s, seg-postpro+nms: 0.206, draw: 1.121
# 0 413 / 959: s202_5
# load+conv: 1.088s, seg-postpro+nms: 0.171, draw: 1.082
# 0 414 / 959: s204_2
# load+conv: 1.066s, seg-postpro+nms: 0.154, draw: 1.065
# 0 415 / 959: s203_2
# load+conv: 1.088s, seg-postpro+nms: 0.155, draw: 1.078
# 0 416 / 959: s204_4
# load+conv: 1.074s, seg-postpro+nms: 0.153, draw: 1.057
# 0 417 / 959: s203_6
# load+conv: 1.130s, seg-postpro+nms: 0.171, draw: 1.095
# 0 418 / 959: s203_4
# load+conv: 1.071s, seg-postpro+nms: 0.167, draw: 1.077
# 0 419 / 959: s204_3
# load+conv: 1.055s, seg-postpro+nms: 0.160, draw: 1.071
# 0 420 / 959: s203_5
# load+conv: 1.088s, seg-postpro+nms: 0.168, draw: 1.091
# 0 421 / 959: s204_1
# load+conv: 1.057s, seg-postpro+nms: 0.160, draw: 1.078
# 0 422 / 959: s205_4
# load+conv: 1.068s, seg-postpro+nms: 0.142, draw: 1.081
# 0 423 / 959: s205_3
# load+conv: 1.048s, seg-postpro+nms: 0.148, draw: 1.073
# 0 424 / 959: s202_6
# load+conv: 1.106s, seg-postpro+nms: 0.165, draw: 1.079
# 0 425 / 959: s203_1
# load+conv: 1.103s, seg-postpro+nms: 0.156, draw: 1.094
# 0 426 / 959: s205_5
# load+conv: 1.166s, seg-postpro+nms: 0.161, draw: 1.108
# 0 427 / 959: s205_1
# load+conv: 1.171s, seg-postpro+nms: 0.159, draw: 1.112
# 0 428 / 959: s205_6
# load+conv: 1.118s, seg-postpro+nms: 0.158, draw: 1.121
# 0 429 / 959: s204_5
# load+conv: 1.111s, seg-postpro+nms: 0.162, draw: 1.104
# 0 430 / 959: s206_2
# load+conv: 1.096s, seg-postpro+nms: 0.137, draw: 1.110
# 0 431 / 959: s205_2
# load+conv: 1.096s, seg-postpro+nms: 0.159, draw: 1.107
# 0 432 / 959: s203_3
# load+conv: 1.105s, seg-postpro+nms: 0.157, draw: 1.100
# 0 433 / 959: s204_6
# load+conv: 1.120s, seg-postpro+nms: 0.161, draw: 1.117
# 0 434 / 959: s206_1
# load+conv: 1.097s, seg-postpro+nms: 0.154, draw: 1.181
# 0 435 / 959: s217_2
# load+conv: 1.104s, seg-postpro+nms: 0.141, draw: 1.071
# 0 436 / 959: s207_6
# load+conv: 1.097s, seg-postpro+nms: 0.161, draw: 1.076
# 0 437 / 959: s208_5
# load+conv: 1.104s, seg-postpro+nms: 0.137, draw: 1.057
# 0 438 / 959: s20_1
# load+conv: 1.098s, seg-postpro+nms: 0.127, draw: 1.083
# 0 439 / 959: s208_2
# load+conv: 1.088s, seg-postpro+nms: 0.136, draw: 1.065
# 0 440 / 959: s217_1
# load+conv: 1.093s, seg-postpro+nms: 0.138, draw: 1.070
# 0 441 / 959: s206_5
# load+conv: 1.066s, seg-postpro+nms: 0.136, draw: 1.091
# 0 442 / 959: s207_2
# load+conv: 1.096s, seg-postpro+nms: 0.149, draw: 1.074
# 0 443 / 959: s208_4
# load+conv: 1.172s, seg-postpro+nms: 0.136, draw: 1.056
# 0 444 / 959: s208_1
# load+conv: 1.236s, seg-postpro+nms: 0.134, draw: 1.059
# 0 445 / 959: s20_6
# load+conv: 1.089s, seg-postpro+nms: 0.129, draw: 1.026
# 0 446 / 959: s207_1
# load+conv: 1.079s, seg-postpro+nms: 0.165, draw: 1.092
# 0 447 / 959: s206_4
# load+conv: 1.074s, seg-postpro+nms: 0.137, draw: 1.049
# 0 448 / 959: s208_3
# load+conv: 1.088s, seg-postpro+nms: 0.125, draw: 1.055
# 0 449 / 959: s20_3
# load+conv: 1.103s, seg-postpro+nms: 0.126, draw: 1.026
# 0 450 / 959: s207_3
# load+conv: 1.072s, seg-postpro+nms: 0.143, draw: 1.046
# 0 451 / 959: s206_6
# load+conv: 1.095s, seg-postpro+nms: 0.134, draw: 1.075
# 0 452 / 959: s20_5
# load+conv: 1.071s, seg-postpro+nms: 0.123, draw: 1.029
# 0 453 / 959: s20_4
# load+conv: 1.101s, seg-postpro+nms: 0.129, draw: 1.043
# 0 454 / 959: s206_3
# load+conv: 1.108s, seg-postpro+nms: 0.137, draw: 1.157
# 0 455 / 959: s207_5
# load+conv: 1.051s, seg-postpro+nms: 0.169, draw: 1.061
# 0 456 / 959: s20_2
# load+conv: 1.065s, seg-postpro+nms: 0.123, draw: 1.049
# 0 457 / 959: s208_6
# load+conv: 1.071s, seg-postpro+nms: 0.130, draw: 1.026
# 0 458 / 959: s207_4
# load+conv: 1.055s, seg-postpro+nms: 0.150, draw: 1.050
# 0 459 / 959: s220_1
# load+conv: 1.058s, seg-postpro+nms: 0.148, draw: 1.063
# 0 460 / 959: s218_5
# load+conv: 1.054s, seg-postpro+nms: 0.140, draw: 1.030
# 0 461 / 959: s21_3
# load+conv: 1.063s, seg-postpro+nms: 0.146, draw: 1.045
# 0 462 / 959: s219_6
# load+conv: 1.050s, seg-postpro+nms: 0.177, draw: 1.071
# 0 463 / 959: s218_1
# load+conv: 1.044s, seg-postpro+nms: 0.144, draw: 1.040
# 0 464 / 959: s219_2
# load+conv: 1.054s, seg-postpro+nms: 0.170, draw: 1.066
# 0 465 / 959: s218_3
# load+conv: 1.050s, seg-postpro+nms: 0.148, draw: 1.033
# 0 466 / 959: s21_4
# load+conv: 1.075s, seg-postpro+nms: 0.150, draw: 1.027
# 0 467 / 959: s217_6
# load+conv: 1.056s, seg-postpro+nms: 0.143, draw: 1.068
# 0 468 / 959: s217_3
# load+conv: 1.051s, seg-postpro+nms: 0.144, draw: 1.016
# 0 469 / 959: s21_1
# load+conv: 1.072s, seg-postpro+nms: 0.133, draw: 1.083
# 0 470 / 959: s219_3
# load+conv: 1.119s, seg-postpro+nms: 0.192, draw: 1.110
# 0 471 / 959: s218_2
# load+conv: 1.099s, seg-postpro+nms: 0.141, draw: 1.077
# 0 472 / 959: s21_6
# load+conv: 1.129s, seg-postpro+nms: 0.143, draw: 1.105
# 0 473 / 959: s217_5
# load+conv: 1.103s, seg-postpro+nms: 0.152, draw: 11.088
# 0 474 / 959: s219_1
# load+conv: 1.163s, seg-postpro+nms: 0.185, draw: 1.160
# 0 475 / 959: s218_6
# load+conv: 1.091s, seg-postpro+nms: 0.131, draw: 1.059
# 0 476 / 959: s217_4
# load+conv: 1.135s, seg-postpro+nms: 0.142, draw: 1.099
# 0 477 / 959: s219_5
# load+conv: 1.095s, seg-postpro+nms: 0.186, draw: 1.128
# 0 478 / 959: s218_4
# load+conv: 1.113s, seg-postpro+nms: 0.140, draw: 1.085
# 0 479 / 959: s21_2
# load+conv: 1.098s, seg-postpro+nms: 0.136, draw: 1.070
# 0 480 / 959: s21_5
# load+conv: 1.460s, seg-postpro+nms: 0.155, draw: 1.075
# 0 481 / 959: s219_4
# load+conv: 1.093s, seg-postpro+nms: 0.187, draw: 1.124
# 0 482 / 959: s221_5
# load+conv: 1.095s, seg-postpro+nms: 0.134, draw: 1.106
# 0 483 / 959: s222_3
# load+conv: 2.575s, seg-postpro+nms: 0.126, draw: 1.050
# 0 484 / 959: s220_3
# load+conv: 1.158s, seg-postpro+nms: 0.140, draw: 1.088
# 0 485 / 959: s222_2
# load+conv: 1.132s, seg-postpro+nms: 0.125, draw: 1.071
# 0 486 / 959: s221_1
# load+conv: 1.085s, seg-postpro+nms: 0.131, draw: 1.072
# 0 487 / 959: s222_4
# load+conv: 1.092s, seg-postpro+nms: 0.131, draw: 1.079
# 0 488 / 959: s221_4
# load+conv: 1.123s, seg-postpro+nms: 0.141, draw: 1.088
# 0 489 / 959: s222_1
# load+conv: 1.109s, seg-postpro+nms: 0.152, draw: 1.103
# 0 490 / 959: s220_5
# load+conv: 1.152s, seg-postpro+nms: 0.151, draw: 1.131
# 0 491 / 959: s220_2
# load+conv: 1.115s, seg-postpro+nms: 0.148, draw: 1.078
# 0 492 / 959: s221_3
# load+conv: 1.115s, seg-postpro+nms: 0.132, draw: 1.083
# 0 493 / 959: s220_6
# load+conv: 1.109s, seg-postpro+nms: 0.144, draw: 1.070
# 0 494 / 959: s221_2
# load+conv: 1.107s, seg-postpro+nms: 0.136, draw: 1.092
# 0 495 / 959: s221_6
# load+conv: 1.113s, seg-postpro+nms: 0.141, draw: 1.109
# 0 496 / 959: s220_4
# load+conv: 1.124s, seg-postpro+nms: 0.148, draw: 1.090
# 0 497 / 959: s22_1
# load+conv: 1.085s, seg-postpro+nms: 0.133, draw: 1.060
# 0 498 / 959: s222_5
# load+conv: 1.099s, seg-postpro+nms: 0.133, draw: 1.068
# 0 499 / 959: s224_5
# load+conv: 1.098s, seg-postpro+nms: 0.140, draw: 1.063
# 0 500 / 959: s22_2
# load+conv: 1.112s, seg-postpro+nms: 0.136, draw: 1.097
# 0 501 / 959: s22_3
# load+conv: 1.123s, seg-postpro+nms: 0.134, draw: 1.064
# 0 502 / 959: s223_6
# load+conv: 1.103s, seg-postpro+nms: 0.139, draw: 1.094
# 0 503 / 959: s222_6
# load+conv: 1.156s, seg-postpro+nms: 0.137, draw: 1.059
# 0 504 / 959: s224_4
# load+conv: 1.109s, seg-postpro+nms: 0.141, draw: 1.087
# 0 505 / 959: s223_1
# load+conv: 1.109s, seg-postpro+nms: 0.133, draw: 1.053
# 0 506 / 959: s224_2
# load+conv: 1.151s, seg-postpro+nms: 0.146, draw: 1.087
# 0 507 / 959: s224_6
# load+conv: 1.106s, seg-postpro+nms: 0.141, draw: 1.121
# 0 508 / 959: s223_5
# load+conv: 1.116s, seg-postpro+nms: 0.137, draw: 1.088
# 0 509 / 959: s223_3
# load+conv: 1.160s, seg-postpro+nms: 0.134, draw: 1.077
# 0 510 / 959: s223_4
# load+conv: 1.101s, seg-postpro+nms: 0.140, draw: 1.104
# 0 511 / 959: s223_2
# load+conv: 1.118s, seg-postpro+nms: 0.135, draw: 1.054
# 0 512 / 959: s224_1
# load+conv: 1.109s, seg-postpro+nms: 0.138, draw: 1.081
# 0 513 / 959: s224_3
# load+conv: 1.121s, seg-postpro+nms: 0.146, draw: 1.097
# 0 514 / 959: s233_5
# load+conv: 1.133s, seg-postpro+nms: 0.169, draw: 1.107
# 0 515 / 959: s234_3
# load+conv: 1.170s, seg-postpro+nms: 0.149, draw: 1.117
# 0 516 / 959: s22_6
# load+conv: 1.175s, seg-postpro+nms: 0.142, draw: 1.095
# 0 517 / 959: s22_4
# load+conv: 1.171s, seg-postpro+nms: 0.141, draw: 1.083
# 0 518 / 959: s233_1
# load+conv: 1.128s, seg-postpro+nms: 0.163, draw: 1.135
# 0 519 / 959: s234_1
# load+conv: 1.231s, seg-postpro+nms: 0.139, draw: 1.066
# 0 520 / 959: s22_5
# load+conv: 1.164s, seg-postpro+nms: 0.137, draw: 1.074
# 0 521 / 959: s234_4
# load+conv: 1.170s, seg-postpro+nms: 0.145, draw: 1.075
# 0 522 / 959: s233_6
# load+conv: 1.158s, seg-postpro+nms: 0.170, draw: 1.101
# 0 523 / 959: s233_4
# load+conv: 1.130s, seg-postpro+nms: 0.161, draw: 1.105
# 0 524 / 959: s233_3
# load+conv: 1.147s, seg-postpro+nms: 0.168, draw: 1.100
# 0 525 / 959: s233_2
# load+conv: 1.165s, seg-postpro+nms: 0.172, draw: 1.108
# 0 526 / 959: s234_2
# load+conv: 1.132s, seg-postpro+nms: 0.147, draw: 1.114
# 0 527 / 959: s235_6
# load+conv: 1.148s, seg-postpro+nms: 0.150, draw: 1.083
# 0 528 / 959: s236_1
# load+conv: 1.182s, seg-postpro+nms: 0.161, draw: 1.127
# 0 529 / 959: s234_5
# load+conv: 1.145s, seg-postpro+nms: 0.149, draw: 1.093
# 0 530 / 959: s234_6
# load+conv: 1.120s, seg-postpro+nms: 0.140, draw: 1.091
# 0 531 / 959: s235_4
# load+conv: 1.135s, seg-postpro+nms: 0.163, draw: 1.107
# 0 532 / 959: s236_5
# load+conv: 1.170s, seg-postpro+nms: 0.167, draw: 1.095
# 0 533 / 959: s237_3
# load+conv: 1.104s, seg-postpro+nms: 0.156, draw: 1.092
# 0 534 / 959: s237_1
# load+conv: 1.152s, seg-postpro+nms: 0.148, draw: 1.098
# 0 535 / 959: s235_5
# load+conv: 1.172s, seg-postpro+nms: 0.172, draw: 1.103
# 0 536 / 959: s235_3
# load+conv: 1.117s, seg-postpro+nms: 0.169, draw: 1.124
# 0 537 / 959: s235_1
# load+conv: 1.163s, seg-postpro+nms: 0.164, draw: 1.108
# 0 538 / 959: s236_4
# load+conv: 1.154s, seg-postpro+nms: 0.160, draw: 1.185
# 0 539 / 959: s236_3
# load+conv: 1.147s, seg-postpro+nms: 0.157, draw: 1.172
# 0 540 / 959: s236_2
# load+conv: 1.124s, seg-postpro+nms: 0.166, draw: 1.191
# 0 541 / 959: s237_2
# load+conv: 1.138s, seg-postpro+nms: 0.149, draw: 1.187
# 0 542 / 959: s237_4
# load+conv: 1.150s, seg-postpro+nms: 0.162, draw: 1.104
# 0 543 / 959: s235_2
# load+conv: 1.105s, seg-postpro+nms: 0.165, draw: 1.140
# 0 544 / 959: s236_6
# load+conv: 1.134s, seg-postpro+nms: 0.147, draw: 1.082
# 0 545 / 959: s23_2
# load+conv: 1.189s, seg-postpro+nms: 0.141, draw: 1.057
# 0 546 / 959: s240_1
# load+conv: 1.106s, seg-postpro+nms: 0.163, draw: 1.131
# 0 547 / 959: s239_4
# load+conv: 1.179s, seg-postpro+nms: 0.146, draw: 1.076
# 0 548 / 959: s239_1
# load+conv: 1.135s, seg-postpro+nms: 0.148, draw: 1.095
# 0 549 / 959: s23_3
# load+conv: 1.123s, seg-postpro+nms: 0.151, draw: 1.073
# 0 550 / 959: s239_3
# load+conv: 1.098s, seg-postpro+nms: 0.144, draw: 1.090
# 0 551 / 959: s237_6
# load+conv: 1.157s, seg-postpro+nms: 0.156, draw: 1.076
# 0 552 / 959: s239_5
# load+conv: 1.154s, seg-postpro+nms: 0.141, draw: 1.090
# 0 553 / 959: s238_6
# load+conv: 1.092s, seg-postpro+nms: 0.159, draw: 1.077
# 0 554 / 959: s238_3
# load+conv: 1.109s, seg-postpro+nms: 0.176, draw: 1.121
# 0 555 / 959: s237_5
# load+conv: 1.113s, seg-postpro+nms: 0.170, draw: 1.094
# 0 556 / 959: s238_4
# load+conv: 1.108s, seg-postpro+nms: 0.169, draw: 1.116
# 0 557 / 959: s23_5
# load+conv: 1.086s, seg-postpro+nms: 0.141, draw: 1.061
# 0 558 / 959: s238_2
# load+conv: 1.092s, seg-postpro+nms: 0.168, draw: 1.105
# 0 559 / 959: s239_2
# load+conv: 1.108s, seg-postpro+nms: 0.158, draw: 1.112
# 0 560 / 959: s238_5
# load+conv: 1.149s, seg-postpro+nms: 0.157, draw: 1.103
# 0 561 / 959: s23_4
# load+conv: 1.131s, seg-postpro+nms: 0.150, draw: 1.077
# 0 562 / 959: s238_1
# load+conv: 1.139s, seg-postpro+nms: 0.168, draw: 1.101
# 0 563 / 959: s239_6
# load+conv: 1.120s, seg-postpro+nms: 0.157, draw: 1.087
# 0 564 / 959: s23_1
# load+conv: 1.120s, seg-postpro+nms: 0.148, draw: 1.109
# 0 565 / 959: s23_6
# load+conv: 1.161s, seg-postpro+nms: 0.155, draw: 1.086
# 0 566 / 959: s24_6
# load+conv: 1.135s, seg-postpro+nms: 0.137, draw: 1.068
# 0 567 / 959: s240_6
# load+conv: 1.157s, seg-postpro+nms: 0.158, draw: 1.102
# 0 568 / 959: s24_1
# load+conv: 1.144s, seg-postpro+nms: 0.147, draw: 1.083
# 0 569 / 959: s24_4
# load+conv: 1.129s, seg-postpro+nms: 0.142, draw: 1.094
# 0 570 / 959: s25_5
# load+conv: 1.105s, seg-postpro+nms: 0.190, draw: 1.120
# 0 571 / 959: s24_2
# load+conv: 1.148s, seg-postpro+nms: 0.142, draw: 1.053
# 0 572 / 959: s26_3
# load+conv: 1.118s, seg-postpro+nms: 0.164, draw: 1.095
# 0 573 / 959: s24_3
# load+conv: 1.120s, seg-postpro+nms: 0.145, draw: 1.067
# 0 574 / 959: s240_2
# load+conv: 1.106s, seg-postpro+nms: 0.174, draw: 1.123
# 0 575 / 959: s240_4
# load+conv: 1.121s, seg-postpro+nms: 0.161, draw: 1.079
# 0 576 / 959: s25_4
# load+conv: 1.143s, seg-postpro+nms: 0.196, draw: 1.113
# 0 577 / 959: s25_3
# load+conv: 1.131s, seg-postpro+nms: 0.198, draw: 1.133
# 0 578 / 959: s240_5
# load+conv: 1.119s, seg-postpro+nms: 0.162, draw: 1.095
# 0 579 / 959: s25_6
# load+conv: 1.091s, seg-postpro+nms: 0.186, draw: 1.106
# 0 580 / 959: s26_1
# load+conv: 1.122s, seg-postpro+nms: 0.175, draw: 1.160
# 0 581 / 959: s25_2
# load+conv: 1.112s, seg-postpro+nms: 0.200, draw: 1.110
# 0 582 / 959: s240_3
# load+conv: 1.177s, seg-postpro+nms: 0.168, draw: 1.117
# 0 583 / 959: s25_1
# load+conv: 1.092s, seg-postpro+nms: 0.192, draw: 1.103
# 0 584 / 959: s24_5
# load+conv: 1.124s, seg-postpro+nms: 0.146, draw: 1.069
# 0 585 / 959: s26_2
# load+conv: 1.185s, seg-postpro+nms: 0.180, draw: 1.103
# 0 586 / 959: s27_3
# load+conv: 1.114s, seg-postpro+nms: 0.161, draw: 1.102
# 0 587 / 959: s29_6
# load+conv: 1.151s, seg-postpro+nms: 0.183, draw: 1.108
# 0 588 / 959: s28_4
# load+conv: 1.177s, seg-postpro+nms: 0.177, draw: 1.102
# 0 589 / 959: s29_5
# load+conv: 1.179s, seg-postpro+nms: 0.186, draw: 1.094
# 0 590 / 959: s26_4
# load+conv: 1.142s, seg-postpro+nms: 0.198, draw: 1.120
# 0 591 / 959: s28_6
# load+conv: 1.142s, seg-postpro+nms: 0.152, draw: 1.125
# 0 592 / 959: s27_2
# load+conv: 1.138s, seg-postpro+nms: 0.169, draw: 13.686
# 0 593 / 959: s28_2
# load+conv: 1.119s, seg-postpro+nms: 0.169, draw: 1.096
# 0 594 / 959: s28_1
# load+conv: 1.143s, seg-postpro+nms: 0.169, draw: 1.099
# 0 595 / 959: s26_6
# load+conv: 1.165s, seg-postpro+nms: 0.183, draw: 1.120
# 0 596 / 959: s27_5
# load+conv: 1.117s, seg-postpro+nms: 0.180, draw: 1.114
# 0 597 / 959: s29_3
# load+conv: 1.116s, seg-postpro+nms: 0.175, draw: 1.112
# 0 598 / 959: s29_2
# load+conv: 1.102s, seg-postpro+nms: 0.184, draw: 1.113
# 0 599 / 959: s27_6
# load+conv: 1.126s, seg-postpro+nms: 0.178, draw: 1.092
# 0 600 / 959: s28_3
# load+conv: 1.201s, seg-postpro+nms: 0.164, draw: 1.139
# 0 601 / 959: s29_1
# load+conv: 1.160s, seg-postpro+nms: 0.188, draw: 1.093
# 0 602 / 959: s28_5
# load+conv: 1.114s, seg-postpro+nms: 0.155, draw: 1.108
# 0 603 / 959: s29_4
# load+conv: 1.142s, seg-postpro+nms: 0.181, draw: 1.110
# 0 604 / 959: s27_4
# load+conv: 1.099s, seg-postpro+nms: 0.179, draw: 1.094
# 0 605 / 959: s27_1
# load+conv: 1.091s, seg-postpro+nms: 0.173, draw: 1.172
# 0 606 / 959: s26_5
# load+conv: 1.098s, seg-postpro+nms: 0.180, draw: 1.102
# 0 607 / 959: s30_3
# load+conv: 1.111s, seg-postpro+nms: 0.167, draw: 1.093
# 0 608 / 959: s31_1
# load+conv: 1.117s, seg-postpro+nms: 0.171, draw: 1.135
# 0 609 / 959: s2_4
# load+conv: 1.103s, seg-postpro+nms: 0.202, draw: 1.111
# 0 610 / 959: s2_2
# load+conv: 1.176s, seg-postpro+nms: 0.180, draw: 1.114
# 0 611 / 959: s2_5
# load+conv: 1.115s, seg-postpro+nms: 0.179, draw: 1.108
# 0 612 / 959: s30_1
# load+conv: 1.105s, seg-postpro+nms: 0.178, draw: 1.108
# 0 613 / 959: s2_3
# load+conv: 1.100s, seg-postpro+nms: 0.188, draw: 1.132
# 0 614 / 959: s30_5
# load+conv: 1.141s, seg-postpro+nms: 0.174, draw: 1.096
# 0 615 / 959: s2_6
# load+conv: 1.109s, seg-postpro+nms: 0.194, draw: 1.123
# 0 616 / 959: s31_3
# load+conv: 1.137s, seg-postpro+nms: 0.185, draw: 1.131
# 0 617 / 959: s30_4
# load+conv: 1.340s, seg-postpro+nms: 0.171, draw: 1.081
# 0 618 / 959: s30_2
# load+conv: 1.095s, seg-postpro+nms: 0.175, draw: 1.117
# 0 619 / 959: s30_6
# load+conv: 1.136s, seg-postpro+nms: 0.166, draw: 1.090
# 0 620 / 959: s31_5
# load+conv: 1.114s, seg-postpro+nms: 0.169, draw: 1.100
# 0 621 / 959: s2_1
# ...
# 0 745 / 959: s56_4
# load+conv: 1.065s, seg-postpro+nms: 0.161, draw: 1.057
# 0 746 / 959: s56_6
# load+conv: 1.056s, seg-postpro+nms: 0.175, draw: 1.037
# 0 747 / 959: s5_4
# load+conv: 1.059s, seg-postpro+nms: 0.180, draw: 1.061
# 0 748 / 959: s60_3
# load+conv: 1.047s, seg-postpro+nms: 0.156, draw: 1.004
# 0 749 / 959: s5_3
# load+conv: 1.050s, seg-postpro+nms: 0.178, draw: 1.031
# 0 750 / 959: s60_6
# load+conv: 1.045s, seg-postpro+nms: 0.164, draw: 1.047
# 0 751 / 959: s58_3
# load+conv: 1.038s, seg-postpro+nms: 0.164, draw: 1.014
# 0 752 / 959: s60_2
# load+conv: 1.048s, seg-postpro+nms: 0.162, draw: 1.005
# 0 753 / 959: s60_1
# load+conv: 1.038s, seg-postpro+nms: 0.161, draw: 1.000
# 0 754 / 959: s59_5
# load+conv: 1.064s, seg-postpro+nms: 0.159, draw: 1.004
# 0 755 / 959: s5_6
# load+conv: 1.077s, seg-postpro+nms: 0.172, draw: 1.029
# 0 756 / 959: s60_4
# load+conv: 1.058s, seg-postpro+nms: 0.155, draw: 0.990
# 0 757 / 959: s58_4
# load+conv: 1.051s, seg-postpro+nms: 0.164, draw: 1.003
# 0 758 / 959: s59_3
# load+conv: 1.078s, seg-postpro+nms: 0.167, draw: 0.998
# 0 759 / 959: s58_6
# load+conv: 1.073s, seg-postpro+nms: 0.164, draw: 1.048
# 0 760 / 959: s59_6
# load+conv: 1.102s, seg-postpro+nms: 0.166, draw: 1.077
# 0 761 / 959: s5_2
# load+conv: 1.105s, seg-postpro+nms: 0.184, draw: 1.068
# 0 762 / 959: s5_5
# load+conv: 1.176s, seg-postpro+nms: 0.186, draw: 1.087
# 0 763 / 959: s59_2
# load+conv: 1.114s, seg-postpro+nms: 0.174, draw: 1.074
# 0 764 / 959: s5_1
# load+conv: 1.108s, seg-postpro+nms: 0.190, draw: 1.109
# 0 765 / 959: s60_5
# load+conv: 1.117s, seg-postpro+nms: 0.171, draw: 1.069
# 0 766 / 959: s58_5
# load+conv: 1.106s, seg-postpro+nms: 0.170, draw: 1.060
# 0 767 / 959: s59_4
# load+conv: 1.104s, seg-postpro+nms: 0.173, draw: 1.055
# 0 768 / 959: s59_1
# load+conv: 1.099s, seg-postpro+nms: 0.167, draw: 1.078
# 0 769 / 959: s65_1
# load+conv: 1.125s, seg-postpro+nms: 0.192, draw: 1.070
# 0 770 / 959: s63_5
# load+conv: 1.158s, seg-postpro+nms: 0.166, draw: 1.067
# 0 771 / 959: s62_6
# load+conv: 1.100s, seg-postpro+nms: 0.170, draw: 1.048
# 0 772 / 959: s64_1
# load+conv: 1.166s, seg-postpro+nms: 0.171, draw: 1.051
# 0 773 / 959: s64_3
# load+conv: 1.138s, seg-postpro+nms: 0.166, draw: 1.064
# 0 774 / 959: s61_1
# load+conv: 1.117s, seg-postpro+nms: 0.170, draw: 1.055
# 0 775 / 959: s63_3
# load+conv: 1.108s, seg-postpro+nms: 0.168, draw: 1.063
# 0 776 / 959: s63_6
# load+conv: 1.119s, seg-postpro+nms: 0.166, draw: 1.067
# 0 777 / 959: s64_2
# load+conv: 1.110s, seg-postpro+nms: 0.173, draw: 1.040
# 0 778 / 959: s64_5
# load+conv: 1.174s, seg-postpro+nms: 0.178, draw: 1.088
# 0 779 / 959: s61_4
# load+conv: 1.103s, seg-postpro+nms: 0.176, draw: 1.066
# 0 780 / 959: s61_2
# load+conv: 1.119s, seg-postpro+nms: 0.172, draw: 1.050
# 0 781 / 959: s65_2
# load+conv: 1.092s, seg-postpro+nms: 0.202, draw: 1.085
# 0 782 / 959: s62_2
# load+conv: 1.101s, seg-postpro+nms: 0.169, draw: 1.066
# 0 783 / 959: s64_6
# load+conv: 1.100s, seg-postpro+nms: 0.176, draw: 1.067
# 0 784 / 959: s63_1
# load+conv: 1.241s, seg-postpro+nms: 0.171, draw: 1.042
# 0 785 / 959: s61_5
# load+conv: 1.145s, seg-postpro+nms: 0.172, draw: 1.053
# 0 786 / 959: s62_4
# load+conv: 1.104s, seg-postpro+nms: 0.171, draw: 1.045
# 0 787 / 959: s61_3
# load+conv: 1.086s, seg-postpro+nms: 0.174, draw: 1.056
# 0 788 / 959: s63_4
# load+conv: 1.176s, seg-postpro+nms: 0.168, draw: 1.066
# 0 789 / 959: s65_3
# load+conv: 1.103s, seg-postpro+nms: 0.213, draw: 1.086
# 0 790 / 959: s62_1
# load+conv: 1.103s, seg-postpro+nms: 0.169, draw: 1.065
# 0 791 / 959: s62_3
# load+conv: 1.115s, seg-postpro+nms: 0.172, draw: 1.107
# 0 792 / 959: s61_6
# load+conv: 1.098s, seg-postpro+nms: 0.182, draw: 1.052
# 0 793 / 959: s64_4
# load+conv: 1.119s, seg-postpro+nms: 0.171, draw: 1.040
# 0 794 / 959: s63_2
# load+conv: 1.143s, seg-postpro+nms: 0.170, draw: 1.066
# 0 795 / 959: s62_5
# load+conv: 1.131s, seg-postpro+nms: 0.171, draw: 1.033
# 0 796 / 959: s66_3
# load+conv: 1.143s, seg-postpro+nms: 0.178, draw: 1.088
# 0 797 / 959: s68_2
# load+conv: 1.161s, seg-postpro+nms: 0.175, draw: 1.045
# 0 798 / 959: s69_1
# load+conv: 1.120s, seg-postpro+nms: 0.207, draw: 1.105
# 0 799 / 959: s68_5
# load+conv: 1.138s, seg-postpro+nms: 0.172, draw: 1.046
# 0 800 / 959: s68_1
# load+conv: 1.105s, seg-postpro+nms: 0.176, draw: 1.048
# 0 801 / 959: s68_4
# load+conv: 1.151s, seg-postpro+nms: 0.170, draw: 1.031
# 0 802 / 959: s67_6
# load+conv: 1.085s, seg-postpro+nms: 0.176, draw: 1.074
# 0 803 / 959: s66_6
# load+conv: 1.089s, seg-postpro+nms: 0.181, draw: 1.066
# 0 804 / 959: s67_1
# load+conv: 1.102s, seg-postpro+nms: 0.177, draw: 1.087
# 0 805 / 959: s65_4
# load+conv: 1.101s, seg-postpro+nms: 0.199, draw: 1.104
# 0 806 / 959: s66_2
# load+conv: 1.120s, seg-postpro+nms: 0.187, draw: 1.075
# 0 807 / 959: s67_2
# load+conv: 1.129s, seg-postpro+nms: 0.176, draw: 1.085
# 0 808 / 959: s68_3
# load+conv: 1.111s, seg-postpro+nms: 0.179, draw: 1.045
# 0 809 / 959: s67_4
# load+conv: 1.094s, seg-postpro+nms: 0.176, draw: 1.058
# 0 810 / 959: s68_6
# load+conv: 1.108s, seg-postpro+nms: 0.173, draw: 1.055
# 0 811 / 959: s67_5
# load+conv: 1.256s, seg-postpro+nms: 0.181, draw: 1.071
# 0 812 / 959: s66_5
# load+conv: 1.118s, seg-postpro+nms: 0.184, draw: 1.102
# 0 813 / 959: s66_1
# load+conv: 1.141s, seg-postpro+nms: 0.181, draw: 1.076
# 0 814 / 959: s66_4
# load+conv: 1.094s, seg-postpro+nms: 0.181, draw: 1.070
# 0 815 / 959: s65_5
# load+conv: 1.100s, seg-postpro+nms: 0.219, draw: 1.127
# 0 816 / 959: s65_6
# load+conv: 1.143s, seg-postpro+nms: 0.214, draw: 1.093
# 0 817 / 959: s67_3
# load+conv: 1.118s, seg-postpro+nms: 0.185, draw: 1.069
# 0 818 / 959: s71_5
# load+conv: 1.130s, seg-postpro+nms: 0.192, draw: 1.080
# 0 819 / 959: s72_1
# load+conv: 1.118s, seg-postpro+nms: 0.181, draw: 1.062
# 0 820 / 959: s69_3
# load+conv: 1.116s, seg-postpro+nms: 0.204, draw: 1.115
# 0 821 / 959: s69_5
# load+conv: 1.122s, seg-postpro+nms: 0.205, draw: 1.094
# 0 822 / 959: s72_4
# load+conv: 1.137s, seg-postpro+nms: 0.164, draw: 1.062
# 0 823 / 959: s72_5
# load+conv: 1.155s, seg-postpro+nms: 0.164, draw: 1.060
# 0 824 / 959: s6_5
# load+conv: 1.104s, seg-postpro+nms: 0.216, draw: 1.102
# 0 825 / 959: s70_3
# load+conv: 1.178s, seg-postpro+nms: 0.198, draw: 1.101
# 0 826 / 959: s71_3
# load+conv: 1.102s, seg-postpro+nms: 0.186, draw: 1.069
# 0 827 / 959: s6_3
# load+conv: 1.293s, seg-postpro+nms: 0.204, draw: 1.096
# 0 828 / 959: s70_2
# load+conv: 1.167s, seg-postpro+nms: 0.190, draw: 1.082
# 0 829 / 959: s71_1
# load+conv: 1.101s, seg-postpro+nms: 0.187, draw: 1.088
# 0 830 / 959: s71_6
# load+conv: 1.106s, seg-postpro+nms: 0.188, draw: 1.099
# 0 831 / 959: s6_4
# load+conv: 1.109s, seg-postpro+nms: 0.199, draw: 1.109
# 0 832 / 959: s70_6
# load+conv: 1.124s, seg-postpro+nms: 0.193, draw: 1.067
# 0 833 / 959: s70_4
# load+conv: 1.247s, seg-postpro+nms: 0.199, draw: 1.080
# 0 834 / 959: s71_4
# load+conv: 1.121s, seg-postpro+nms: 0.190, draw: 1.074
# 0 835 / 959: s70_1
# load+conv: 1.114s, seg-postpro+nms: 0.194, draw: 1.101
# 0 836 / 959: s72_2
# load+conv: 1.120s, seg-postpro+nms: 0.177, draw: 1.059
# 0 837 / 959: s69_4
# load+conv: 1.087s, seg-postpro+nms: 0.198, draw: 1.035
# 0 838 / 959: s6_1
# load+conv: 1.144s, seg-postpro+nms: 0.197, draw: 1.052
# 0 839 / 959: s71_2
# load+conv: 1.047s, seg-postpro+nms: 0.183, draw: 1.019
# 0 840 / 959: s72_3
# load+conv: 1.083s, seg-postpro+nms: 0.170, draw: 0.991
# 0 841 / 959: s69_2
# load+conv: 1.093s, seg-postpro+nms: 0.203, draw: 1.028
# 0 842 / 959: s70_5
# load+conv: 1.077s, seg-postpro+nms: 0.187, draw: 1.062
# 0 843 / 959: s6_6
# load+conv: 1.097s, seg-postpro+nms: 0.203, draw: 1.137
# 0 844 / 959: s69_6
# load+conv: 1.101s, seg-postpro+nms: 0.212, draw: 1.126
# 0 845 / 959: s6_2
# load+conv: 1.151s, seg-postpro+nms: 0.205, draw: 1.115
# 0 846 / 959: s76_5
# load+conv: 1.204s, seg-postpro+nms: 0.179, draw: 1.084
# 0 847 / 959: s73_3
# load+conv: 1.114s, seg-postpro+nms: 0.217, draw: 1.109
# 0 848 / 959: s74_3
# load+conv: 1.134s, seg-postpro+nms: 0.206, draw: 1.122
# 0 849 / 959: s73_1
# load+conv: 1.133s, seg-postpro+nms: 0.191, draw: 1.079
# 0 850 / 959: s76_4
# load+conv: 1.121s, seg-postpro+nms: 0.189, draw: 1.030
# 0 851 / 959: s73_6
# load+conv: 1.107s, seg-postpro+nms: 0.193, draw: 1.074
# 0 852 / 959: s77_2
# load+conv: 1.090s, seg-postpro+nms: 0.187, draw: 1.042
# 0 853 / 959: s72_6
# load+conv: 1.058s, seg-postpro+nms: 0.179, draw: 1.014
# 0 854 / 959: s76_6
# load+conv: 1.081s, seg-postpro+nms: 0.183, draw: 1.035
# 0 855 / 959: s74_2
# load+conv: 1.101s, seg-postpro+nms: 0.204, draw: 1.057
# 0 856 / 959: s74_6
# load+conv: 1.103s, seg-postpro+nms: 0.204, draw: 1.087
# 0 857 / 959: s75_1
# load+conv: 1.061s, seg-postpro+nms: 0.208, draw: 1.076
# 0 858 / 959: s77_6
# load+conv: 1.076s, seg-postpro+nms: 0.191, draw: 1.043
# 0 859 / 959: s77_1
# load+conv: 1.084s, seg-postpro+nms: 0.197, draw: 1.046
# 0 860 / 959: s74_5
# load+conv: 1.104s, seg-postpro+nms: 0.198, draw: 1.051
# 0 861 / 959: s74_1
# load+conv: 1.203s, seg-postpro+nms: 0.219, draw: 1.110
# 0 862 / 959: s78_1
# load+conv: 1.078s, seg-postpro+nms: 0.198, draw: 1.055
# 0 863 / 959: s76_2
# load+conv: 1.183s, seg-postpro+nms: 0.181, draw: 1.033
# 0 864 / 959: s75_3
# load+conv: 1.083s, seg-postpro+nms: 0.215, draw: 1.067
# 0 865 / 959: s75_4
# load+conv: 1.106s, seg-postpro+nms: 0.221, draw: 1.068
# 0 866 / 959: s75_2
# load+conv: 1.107s, seg-postpro+nms: 0.200, draw: 1.090
# 0 867 / 959: s73_5
# load+conv: 1.065s, seg-postpro+nms: 0.206, draw: 1.063
# 0 868 / 959: s77_4
# load+conv: 1.103s, seg-postpro+nms: 0.191, draw: 1.045
# 0 869 / 959: s78_2
# load+conv: 1.066s, seg-postpro+nms: 0.185, draw: 1.045
# 0 870 / 959: s73_2
# load+conv: 1.068s, seg-postpro+nms: 0.200, draw: 1.056
# 0 871 / 959: s76_1
# load+conv: 1.055s, seg-postpro+nms: 0.196, draw: 1.071
# 0 872 / 959: s77_5
# load+conv: 1.070s, seg-postpro+nms: 0.193, draw: 1.036
# 0 873 / 959: s73_4
# load+conv: 1.059s, seg-postpro+nms: 0.211, draw: 1.091
# 0 874 / 959: s77_3
# load+conv: 1.067s, seg-postpro+nms: 0.201, draw: 1.055
# 0 875 / 959: s74_4
# load+conv: 1.094s, seg-postpro+nms: 0.195, draw: 1.039
# 0 876 / 959: s75_6
# load+conv: 1.067s, seg-postpro+nms: 0.203, draw: 1.087
# 0 877 / 959: s75_5
# load+conv: 1.081s, seg-postpro+nms: 0.209, draw: 1.066
# 0 878 / 959: s79_3
# load+conv: 1.070s, seg-postpro+nms: 0.192, draw: 1.048
# 0 879 / 959: s78_6
# load+conv: 1.082s, seg-postpro+nms: 0.211, draw: 1.104
# 0 880 / 959: s7_1
# load+conv: 1.116s, seg-postpro+nms: 0.196, draw: 1.038
# 0 881 / 959: s78_4
# load+conv: 1.102s, seg-postpro+nms: 0.199, draw: 1.079
# 0 882 / 959: s79_1
# load+conv: 1.108s, seg-postpro+nms: 0.206, draw: 1.145
# 0 883 / 959: s80_2
# load+conv: 1.115s, seg-postpro+nms: 0.190, draw: 1.103
# 0 884 / 959: s78_3
# load+conv: 1.091s, seg-postpro+nms: 0.213, draw: 1.067
# 0 885 / 959: s78_5
# load+conv: 1.129s, seg-postpro+nms: 0.188, draw: 1.036
# 0 886 / 959: s7_6
# load+conv: 1.089s, seg-postpro+nms: 0.206, draw: 1.066
# 0 887 / 959: s7_2
# load+conv: 1.123s, seg-postpro+nms: 0.201, draw: 1.045
# 0 888 / 959: s80_1
# load+conv: 1.131s, seg-postpro+nms: 0.213, draw: 1.064
# 0 889 / 959: s79_6
# load+conv: 1.082s, seg-postpro+nms: 0.193, draw: 1.082
# 0 890 / 959: s7_5
# load+conv: 1.134s, seg-postpro+nms: 0.269, draw: 1.092
# 0 891 / 959: s80_4
# load+conv: 1.077s, seg-postpro+nms: 0.184, draw: 1.022
# 0 892 / 959: s80_3
# load+conv: 1.101s, seg-postpro+nms: 0.189, draw: 1.047
# 0 893 / 959: s79_2
# load+conv: 1.081s, seg-postpro+nms: 0.200, draw: 1.060
# 0 894 / 959: s79_4
# load+conv: 1.080s, seg-postpro+nms: 0.181, draw: 1.030
# 0 895 / 959: s79_5
# load+conv: 1.099s, seg-postpro+nms: 0.188, draw: 1.064
# 0 896 / 959: s7_4
# load+conv: 1.435s, seg-postpro+nms: 0.193, draw: 1.052
# 0 897 / 959: s7_3
# load+conv: 1.064s, seg-postpro+nms: 0.204, draw: 1.076
# 0 898 / 959: s82_2
# load+conv: 1.109s, seg-postpro+nms: 0.219, draw: 1.070
# 0 899 / 959: s83_4
# load+conv: 1.105s, seg-postpro+nms: 0.223, draw: 1.067
# 0 900 / 959: s82_6
# load+conv: 1.081s, seg-postpro+nms: 0.196, draw: 1.077
# 0 901 / 959: s83_2
# load+conv: 1.079s, seg-postpro+nms: 0.226, draw: 1.067
# 0 902 / 959: s81_2
# load+conv: 1.079s, seg-postpro+nms: 0.228, draw: 1.096
# 0 903 / 959: s83_5
# load+conv: 1.112s, seg-postpro+nms: 0.212, draw: 1.068
# 0 904 / 959: s84_1
# load+conv: 1.074s, seg-postpro+nms: 0.231, draw: 1.068
# 0 905 / 959: s80_5
# load+conv: 1.070s, seg-postpro+nms: 0.190, draw: 1.066
# 0 906 / 959: s82_3
# load+conv: 1.119s, seg-postpro+nms: 0.209, draw: 1.065
# 0 907 / 959: s82_4
# load+conv: 1.076s, seg-postpro+nms: 0.218, draw: 1.063
# 0 908 / 959: s82_5
# load+conv: 1.104s, seg-postpro+nms: 0.200, draw: 1.065
# 0 909 / 959: s81_5
# load+conv: 1.076s, seg-postpro+nms: 0.257, draw: 1.069
# 0 910 / 959: s84_2
# load+conv: 1.087s, seg-postpro+nms: 0.234, draw: 1.106
# 0 911 / 959: s83_1
# load+conv: 1.104s, seg-postpro+nms: 0.231, draw: 1.078
# 0 912 / 959: s80_6
# load+conv: 1.080s, seg-postpro+nms: 0.193, draw: 1.020
# 0 913 / 959: s83_6
# load+conv: 1.167s, seg-postpro+nms: 0.226, draw: 1.095
# 0 914 / 959: s81_4
# load+conv: 1.072s, seg-postpro+nms: 0.225, draw: 1.077
# 0 915 / 959: s82_1
# load+conv: 1.057s, seg-postpro+nms: 0.225, draw: 1.085
# 0 916 / 959: s83_3
# load+conv: 1.079s, seg-postpro+nms: 0.228, draw: 1.067
# 0 917 / 959: s81_3
# load+conv: 1.068s, seg-postpro+nms: 0.240, draw: 1.083
# 0 918 / 959: s81_6
# load+conv: 1.106s, seg-postpro+nms: 0.220, draw: 1.075
# 0 919 / 959: s81_1
# load+conv: 1.087s, seg-postpro+nms: 0.248, draw: 1.070
# 0 920 / 959: s84_3
# load+conv: 1.120s, seg-postpro+nms: 0.227, draw: 1.088
# 0 921 / 959: s85_2
# load+conv: 1.075s, seg-postpro+nms: 0.212, draw: 1.062
# 0 922 / 959: s84_5
# load+conv: 1.068s, seg-postpro+nms: 0.240, draw: 1.067
# 0 923 / 959: s84_4
# load+conv: 1.079s, seg-postpro+nms: 0.224, draw: 1.093
# 0 924 / 959: s87_4
# load+conv: 1.060s, seg-postpro+nms: 0.219, draw: 1.068
# 0 925 / 959: s86_6
# load+conv: 1.084s, seg-postpro+nms: 0.216, draw: 1.064
# 0 926 / 959: s87_2
# load+conv: 1.089s, seg-postpro+nms: 0.220, draw: 1.068
# 0 927 / 959: s85_4
# load+conv: 1.092s, seg-postpro+nms: 0.221, draw: 20.985
# 0 928 / 959: s85_6
# load+conv: 1.086s, seg-postpro+nms: 0.214, draw: 1.092
# 0 929 / 959: s86_2
# load+conv: 1.084s, seg-postpro+nms: 0.227, draw: 1.074
# 0 930 / 959: s86_3
# load+conv: 1.116s, seg-postpro+nms: 0.214, draw: 1.064
# 0 931 / 959: s86_1
# load+conv: 1.126s, seg-postpro+nms: 0.215, draw: 1.095
# 0 932 / 959: s87_1
# load+conv: 1.058s, seg-postpro+nms: 0.224, draw: 1.060
# 0 933 / 959: s84_6
# load+conv: 1.077s, seg-postpro+nms: 0.236, draw: 1.062
# 0 934 / 959: s87_3
# load+conv: 1.090s, seg-postpro+nms: 0.211, draw: 1.058
# 0 935 / 959: s86_5
# load+conv: 1.091s, seg-postpro+nms: 0.209, draw: 1.057
# 0 936 / 959: s85_5
# load+conv: 1.066s, seg-postpro+nms: 0.227, draw: 1.282
# 0 937 / 959: s85_3
# load+conv: 1.092s, seg-postpro+nms: 0.219, draw: 1.062
# 0 938 / 959: s86_4
# load+conv: 1.096s, seg-postpro+nms: 0.214, draw: 1.055
# 0 939 / 959: s85_1
# load+conv: 1.130s, seg-postpro+nms: 0.216, draw: 1.098
# 0 940 / 959: s8_5
# load+conv: 1.095s, seg-postpro+nms: 0.218, draw: 1.095
# 0 941 / 959: s88_2
# load+conv: 1.118s, seg-postpro+nms: 0.266, draw: 1.135
# 0 942 / 959: s87_5
# load+conv: 1.116s, seg-postpro+nms: 0.244, draw: 1.103
# 0 943 / 959: s8_6
# load+conv: 1.225s, seg-postpro+nms: 0.239, draw: 1.105
# 0 944 / 959: s88_5
# load+conv: 1.099s, seg-postpro+nms: 0.247, draw: 1.127
# 0 945 / 959: s88_1
# load+conv: 1.092s, seg-postpro+nms: 0.248, draw: 1.101
# 0 946 / 959: s8_4
# load+conv: 1.115s, seg-postpro+nms: 0.210, draw: 1.099
# 0 947 / 959: s87_6
# load+conv: 1.102s, seg-postpro+nms: 0.220, draw: 1.078
# 0 948 / 959: s9_5
# load+conv: 1.103s, seg-postpro+nms: 0.230, draw: 1.098
# 0 949 / 959: s8_1
# load+conv: 1.125s, seg-postpro+nms: 0.238, draw: 1.091
# 0 950 / 959: s9_6
# load+conv: 1.079s, seg-postpro+nms: 0.224, draw: 1.074
# 0 951 / 959: s88_3
# load+conv: 1.089s, seg-postpro+nms: 0.222, draw: 1.100
# 0 952 / 959: s9_2
# load+conv: 1.063s, seg-postpro+nms: 0.218, draw: 1.073
# 0 953 / 959: s8_3
# load+conv: 1.075s, seg-postpro+nms: 0.228, draw: 1.080
# 0 954 / 959: s8_2
# load+conv: 1.099s, seg-postpro+nms: 0.236, draw: 1.104
# 0 955 / 959: s88_4
# load+conv: 1.090s, seg-postpro+nms: 0.229, draw: 1.080
# 0 956 / 959: s9_3
# load+conv: 1.087s, seg-postpro+nms: 0.232, draw: 1.074
# 0 957 / 959: s9_4
# load+conv: 1.130s, seg-postpro+nms: 0.223, draw: 1.065
# 0 958 / 959: s88_6
# load+conv: 1.080s, seg-postpro+nms: 0.256, draw: 1.080
# 0 959 / 959: s9_1
# load+conv: 1.109s, seg-postpro+nms: 0.226, draw: 1.091
# Average: load+conv: 1.114s, oir-select+seg-post+nms: 0.147, draw: 1.172
